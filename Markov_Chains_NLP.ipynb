# %% [markdown]
# Source: [Princeton Assignment](https://www.cs.princeton.edu/courses/archive/fall13/cos126/assignments/markov.html)
#
# **Markov Chains:** the next state of a process only depends on the previous state (this is also considered as memoryless)
#
# Markov Chains can be represented as a dictionary in Python
#
# ```
# {
# 'you': ['know', 'all', 'about],
# 'everyone': ['is', 'says'],
# 'says': ['friends']
# }
# ```
# Every word in a corpus as a state. The next word is only dependent on the previous word (Markov Chain). We can start with a word and have the next word randomly generated, one at a time
#
# Pseudocode:
# 1. create a dictionary for corpus (each word) where the **keys are the current state** and the **values are the options for the next state**
# 2. create a function to randomly generate next terms
# 3. output: comedy routines in the style of each comedian
#
# This pseudocode is oversimplified way of generating text. A much more complex technique would be to use deep learning and **Long Short-Term Memory (LSTM)** (Source: [Brandon Rohrer](https://www.youtube.com/watch?v=WCUNPb-5EYI)). This not only takes into account the previous word, but things like the words before the previous word, what words have already been generated

# %% [markdown]
# ### 1. Read the dataset

# %%
import pandas as pd

# Read the CSV file and set 'Unnamed: 0' as the index column
quotes_df = pd.read_csv('inspiration.csv', index_col='Unnamed: 0')
quotes_df.head()
# Out:
#     Category                                              Quote  \
# 0       LOVE                      Let us see what love can do.
# 1       LOVE  We can’t heal the world today. But we can begi...
# 2  LISTENING  Listen with curiosity. Speak with honesty. Act...
# 3  LISTENING  The most basic and powerful way to connect to ...
# 4  LISTENING             Knowledge speaks, but wisdom listens.
#
#                                           Image-link  \
# 0  https://assets.passiton.com/quotes/quote_artwo...
# 1  https://assets.passiton.com/quotes/quote_artwo...
# 2  https://assets.passiton.com/quotes/quote_artwo...
# 3  https://assets.passiton.com/quotes/quote_artwo...
# 4  https://assets.passiton.com/quotes/quote_artwo...
#
#                                            Quote-url
# 0  /inspirational-quotes/6900-let-us-see-what-lov...
# 1  /inspirational-quotes/8169-we-can-t-heal-the-w...
# 2  /inspirational-quotes/8083-listen-with-curiosi...
# 3  /inspirational-quotes/7139-the-most-basic-and-...
# 4  /inspirational-quotes/8376-knowledge-speaks-bu...

# %%
# find the top 3 category
quotes_df['Category'].value_counts()[:3]
# Out:
# Category
# LOVE        54
# HOPE        41
# KINDNESS    39
# Name: count, dtype: int64

# %%
# extract only 2 columns from the original dataset
quotes_df = quotes_df[['Category', 'Quote']]

# extract only the top 3 category quotes from the dataset
love_hope_kindness_quotes = quotes_df[quotes_df['Category'].isin(['LOVE', 'HOPE', 'KINDNESS'])]

love_hope_kindness_quotes.head()
# Out:
#     Category                                              Quote
# 0       LOVE                      Let us see what love can do.
# 1       LOVE  We can’t heal the world today. But we can begi...
# 22  KINDNESS  Ask yourself: Have you been kind today? Make k...
# 23  KINDNESS       One kind word can warm three winter months.
# 24  KINDNESS  You can be rich in spirit, kindness, love and ...

# %% [markdown]
# ### 2. Build a Markov Chain Function
# We are going to build a simple Markov chain function that creates a dictionary:
#
# *  The keys should be all of the words in the corpus
# *  The values should be a list of the words that follow the keys

# %%
# combine them into a giant string
quotes = love_hope_kindness_quotes['Quote'].str.cat()

# read the first 100 characters
quotes[:100]
# Out:
# 'Let us see what love can do. We can’t heal the world today. But we can begin with a voice of compass'

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''

    # Tokenize the text by word, though including punctuation
    words = text.split(' ')

    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list) # defaultdict(list, {})

    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
chain = markov_chain(quotes)
chain
# Out:
# {'Let': ['us', 'no', 'your', 'your', 'the'],
#  'us': ['see', 'as', 'is', 'also'],
#  'see': ['what', 'the', 'them.'],
#  'what': ['love',
#   'they',
#   'we',
#   'kindness',
#   'you',
#   'happens',
#   'you',
#   'you',
#   'you',
#   'you',
#   'happens',
#   'you'],
#  'love': ['can',
#   'and',
#   'to',
#   'to',
#   'and',
#   'and',
#   'and',
#   'there',
#   'everyone',
#   'and',
#   'like',
#   'everywhere',
#   'and',
#   'we',
#   'we',
#   'to',
#   'to',
#   'in',
#   "'til",
#   'and',
#   'be',
#   'and',
#   'something,',
#   'alike.',
#   'and',
#   'of',
#   'and',
#   'and',
#   'lately,',
#   'is',
#   'will',
#   'like',
#   'that'],
#  'can': ['do.',
#   'begin',
#   'warm',
#   'be',
#   'you',
#   'go',
#   'turn',
#   'live',
#   'always,',
#   'accomplish',
#   'make',
#   'bear',
#   'bring.',
#   'become',
#   'accomplish',
#   'be',
#   'make',
#   'hear',
#   'see.',
#   'be',
#   'inspire',
#   'happen,',
#   'be.',
#   'find',
#   'hold.'],
#  'do.': ['We', 'Where', 'And', 'Love'],
#  'We': ['can’t',
#   'should',
#   'lose',
#   'find',
#   'rise',
#   'must',
#   'have',
#   'don’t',
#   'are',
#   'must',
#   'need',
#   'always',
#   'are'],
#  'can’t': ['heal'],
#  'heal': ['the'],
#  'the': ['world',
#   'world.',
#   'betterment',
#   'lost',
#   'lonely.',
#   'invisible,',
#   'intangible,',
#   'impossible.',
#   'thing',
#   'soul',
#   'tunes',
#   'words',
#   'darkest',
#   'brightest',
#   'spirit',
#   'spirit',
#   'things',
#   'entire',
#   'world.',
#   'roots',
#   'world?',
#   'heart.',
#   'knowledge',
#   'same',
#   'touch',
#   'world.',
#   'same',
#   'past,',
#   'future.',
#   'hope,',
#   'belief,',
#   'conviction',
#   'horizon.',
#   'threshold',
#   'year',
#   'lives',
#   'Sun',
#   'Earth,‘You',
#   'sky.',
#   'season',
#   'whole',
#   'most',
#   'riddle',
#   'qualities',
#   'yesterdays.',
#   'possible.',
#   'mark',
#   'world.',
#   'one',
#   'giver.',
#   'most',
#   'dark,',
#   'stubborn',
#   'right',
#   'dawn',
#   'hope',
#   'darkness',
#   'sunshine.',
#   'present',
#   'common',
#   'flame',
#   'only',
#   'sun',
#   'third',
#   'pool',
#   'world',
#   'Grinch,',
#   'snow,',
#   'Grinch',
#   'deaf',
#   'blind',
#   'sun,',
#   'shadow',
#   'moment,',
#   'darkest',
#   'light.',
#   'grandest',
#   'beauty',
#   'thanks',
#   'act',
#   'person',
#   'most',
#   'the',
#   'most',
#   'only',
#   'imagination,',
#   'faith',
#   'courage',
#   'only',
#   'world',
#   'joy',
#   'spirit',
#   'mind.',
#   'spirit.',
#   "mustn'ts,",
#   "don'ts.",
#   "shouldn'ts,",
#   'impossibles,',
#   "won'ts.",
#   'never',
#   'common',
#   'flame',
#   'sun',
#   'heart',
#   'world',
#   'truth.',
#   'big',
#   'little',
#   'people',
#   'world',
#   'best',
#   'storm.',
#   'memory',
#   'sun',
#   'earth,',
#   'whole',
#   'human',
#   'individual',
#   'results',
#   'noise',
#   'courage'],
#  'world': ['today.', 'in', 'with', 'will', 'to', 'would'],
#  'today.': ['But', 'All'],
#  'But': ['we'],
#  'we': ['can',
#   'have',
#   'see',
#   'love.',
#   'must',
#   'change',
#   'all',
#   'leave',
#   'will',
#   'believe',
#   'can',
#   'give',
#   'keep.',
#   'love',
#   'must',
#   'journey',
#   'feel',
#   'are'],
#  'begin': ['with'],
#  'with': ['a',
#   'action.',
#   'feathers',
#   'ambition',
#   'kindness,',
#   'no',
#   'kind',
#   'love',
#   'each',
#   'its',
#   'hope,',
#   'hope.',
#   'his',
#   'no',
#   'kindness',
#   'a',
#   'the'],
#  'a': ['voice',
#   'heart',
#   'dollar',
#   'simple',
#   'kinder',
#   'time.',
#   'random',
#   'poet.',
#   'night',
#   'problem',
#   'state',
#   'better',
#   'better',
#   'small',
#   'tidal',
#   'statement',
#   'conspiracy',
#   'little',
#   'moment',
#   'passion',
#   'difference.',
#   'person',
#   'hardship',
#   'warmth',
#   'richness',
#   'difference.',
#   'gift—freely,',
#   'person',
#   'fish.',
#   'powerful',
#   'light',
#   'store?',
#   'little',
#   'language',
#   'force',
#   'moment,',
#   'few,',
#   'friendship',
#   'problem',
#   'small',
#   'ripple',
#   'love',
#   'wonder',
#   'dreamer,',
#   'philosophy',
#   'philosophy',
#   'Prism.\nMay',
#   'person',
#   'simple',
#   'good',
#   'resting',
#   'shelter',
#   'love'],
#  'voice': ['of'],
#  'of': ['compassion,',
#   'love,',
#   'kindness.',
#   'who',
#   'who',
#   'personkind,',
#   'equality',
#   'this',
#   'love',
#   'good',
#   'good',
#   'kindness',
#   'our',
#   'kindness',
#   'kindness,',
#   'reward,',
#   'loving',
#   'love',
#   'mind,',
#   'the',
#   'the',
#   'kindness',
#   'kindness',
#   'many.',
#   'love',
#   'love.',
#   'how',
#   'human',
#   'the',
#   'loving',
#   'life,',
#   'something',
#   'our',
#   'times,',
#   'kindness',
#   'what',
#   'kindness.',
#   'us',
#   'all,',
#   'learning.',
#   'those',
#   'everything,',
#   'kindness,',
#   'their',
#   'life.',
#   'the',
#   'the',
#   'kindness',
#   'life,',
#   'each',
#   'things,',
#   'trouble',
#   'love',
#   'the',
#   'other',
#   'other’s'],
#  'compassion,': ['a'],
#  'heart': ['of', 'and', "wasn't", 'can', 'and'],
#  'love,': ['and', 'something', 'something', 'and', 'time'],
#  'and': ['an',
#   'change',
#   'all',
#   'love',
#   'achieves',
#   'sings',
#   'never',
#   'laughter',
#   'warm',
#   'home.',
#   'faithful',
#   'the',
#   'compassion',
#   'kindness.',
#   'affection.',
#   'the',
#   'make',
#   'dedication.',
#   'inspiration,',
#   'powerful',
#   'time',
#   'truth.',
#   'compassion-',
#   'where',
#   'care',
#   'propel',
#   'invitations,',
#   'kindness',
#   'they',
#   'most',
#   'try',
#   'watch',
#   'work:',
#   'difficulties',
#   'into',
#   'something',
#   'being',
#   'a',
#   'kindness',
#   'supplies',
#   'without',
#   'all',
#   'hostility',
#   'something',
#   'do',
#   'make',
#   'hold',
#   'puzzling,',
#   'puzzled',
#   'the',
#   'hope',
#   'offer',
#   'be',
#   'do',
#   'to',
#   'your',
#   'when',
#   'kindness',
#   'cared',
#   'peace.',
#   'instill',
#   'in',
#   'impossible',
#   'produces',
#   'feel',
#   'rebound',
#   'supplies',
#   'be',
#   'ears',
#   'the',
#   'have',
#   'you',
#   'be',
#   'how',
#   'live',
#   'no',
#   'in',
#   'the',
#   'loves',
#   'intuition.'],
#  'an': ['act', 'ability', 'impact', 'essential', 'experience'],
#  'act': ['of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'of',
#   'itself.',
#   'of',
#   'creates',
#   'of',
#   'of'],
#  'kindness.': ['Ask', 'What', 'We', 'Know', 'Every'],
#  'Ask': ['yourself:'],
#  'yourself:': ['Have'],
#  'Have': ['you'],
#  'you': ['been',
#   "can't",
#   'are.',
#   'may',
#   'are;',
#   'can.',
#   'find',
#   'really',
#   'can',
#   'go.',
#   'without',
#   'can.',
#   'cannot',
#   'just',
#   "don't",
#   'need',
#   'spell',
#   'least',
#   'go',
#   'will',
#   'will',
#   'know',
#   'hope',
#   'can',
#   'feel,',
#   'do.',
#   'give',
#   'choose',
#   'in',
#   'more',
#   'love',
#   'do.',
#   'really',
#   'get.',
#   'think',
#   'Reach',
#   'go',
#   'are',
#   'will',
#   "haven't",
#   'love',
#   'mean',
#   'comfort,',
#   'warm,',
#   'are',
#   'home.\n',
#   'truly'],
#  'been': ['kind', 'kindness,'],
#  'kind': ['today?', 'word', 'hearts.', 'by'],
#  'today?': ['Make'],
#  'Make': ['kindness', 'it', 'your', 'your'],
#  'kindness': ['your',
#   'throws',
#   'with',
#   'at',
#   'is.',
#   'is',
#   'may',
#   'may',
#   'to',
#   'are',
#   'what',
#   'is',
#   'are',
#   'can',
#   'causes',
#   'gathers',
#   'is',
#   'toward',
#   'one',
#   'toward'],
#  'your': ['modus',
#   'world.',
#   'life',
#   'own',
#   'own',
#   'days,',
#   'heart',
#   'love',
#   'little',
#   'hopes,',
#   'hurts,',
#   'future.',
#   'hook',
#   'heart',
#   'prayers',
#   'community',
#   'fears,',
#   'hopes',
#   'dreams.',
#   'Hurts',
#   'Deepest',
#   'arms',
#   'eyes',
#   'best.',
#   'blessings.',
#   'days',
#   'own',
#   'heart'],
#  'modus': ['operandi'],
#  'operandi': ['and'],
#  'change': ['your', 'the'],
#  'world.': ['', 'Infuse', 'A', 'Hope,', 'Love', 'The'],
#  '': ['One',
#   'That’s',
#   'You',
#   'How',
#   'Kindness',
#   'Remember',
#   'Listen',
#   'There'],
#  'One': ['kind', 'random'],
#  'word': ['can'],
#  'warm': ['three', 'your'],
#  'three': ['winter', 'things', 'things'],
#  'winter': ['months.'],
#  'months.': ['You'],
#  'You': ['can',
#   'yourself,',
#   'always',
#   'can',
#   'can',
#   'wait',
#   'feel',
#   'may',
#   'can'],
#  'be': ['rich',
#   'found',
#   'determined',
#   'creating',
#   'yours',
#   "happier'...",
#   'a',
#   'a',
#   'the',
#   'healed',
#   'led',
#   'happy',
#   'better,',
#   'loved,',
#   'yours!',
#   'kind.',
#   'kind.',
#   'kind.',
#   'truly',
#   'always',
#   'a',
#   'a',
#   'so?',
#   'found',
#   'answered',
#   'seen',
#   'what',
#   'loved.',
#   'kind.',
#   'solved',
#   'loved.',
#   'completely',
#   'prepared',
#   'loved',
#   'kind.',
#   'loved',
#   'trapped'],
#  'rich': ['in'],
#  'in': ['spirit,',
#   'return,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'all',
#   'every',
#   'the',
#   'action',
#   'this',
#   'life',
#   'a',
#   'peace,',
#   'kindness',
#   'the',
#   'this',
#   'human',
#   'this',
#   'the',
#   'it,',
#   'the',
#   'your',
#   'even',
#   'wondrous',
#   'a',
#   'life.',
#   'life',
#   'your',
#   'our',
#   'dreams,',
#   'imagination',
#   'the',
#   'spite',
#   'words.',
#   'a',
#   'this',
#   'return.',
#   'those',
#   'this;'],
#  'spirit,': ['kindness,'],
#  'kindness,': ['love', 'always.', 'with', 'beauty', 'no'],
#  'all': ['those',
#   'directions,',
#   'this',
#   'share.',
#   'good',
#   'of',
#   'my',
#   'that',
#   'your',
#   'else,',
#   'the',
#   'this'],
#  'those': ['things',
#   'little',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'who',
#   'times'],
#  'things': ['that',
#   'for',
#   'we',
#   'are',
#   'to',
#   'will',
#   'in',
#   'to',
#   'to',
#   'happen,',
#   'happen,',
#   'and',
#   'in'],
#  'that': ['you',
#   'there',
#   'it',
#   'perches',
#   'we',
#   'overwhelm',
#   'important.',
#   'one',
#   'is',
#   'could',
#   'things',
#   'there',
#   'over',
#   'define',
#   'if',
#   'troubles',
#   'they',
#   'tomorrow',
#   'nothing',
#   'heats',
#   'treasure,',
#   'has',
#   'lifts',
#   'sets',
#   'for',
#   'ever',
#   'leads',
#   'I',
#   'people',
#   'cannot',
#   'you',
#   'heats',
#   'you',
#   'tomorrow',
#   'he',
#   'people'],
#  "can't": ['put'],
#  'put': ['a', 'together', 'there'],
#  'dollar': ['sign'],
#  'sign': ['on.'],
#  'on.': ['Do'],
#  'Do': ['things', 'your'],
#  'for': ['people',
#   'it',
#   'something.',
#   'others,',
#   'the',
#   'someone',
#   'you.',
#   'those',
#   'something',
#   'my',
#   'this',
#   'the',
#   'good',
#   'most',
#   'all',
#   'every',
#   'every',
#   'all',
#   'those',
#   'those',
#   'those',
#   'those',
#   'those',
#   'those'],
#  'people': ['not', 'by', 'with', 'are', 'and', 'you', 'just'],
#  'not': ['because',
#   'enough',
#   'doing',
#   'dominate;',
#   'do',
#   'my',
#   'of',
#   'the',
#   'your',
#   'pretending',
#   'feel',
#   'only',
#   'last.',
#   'think',
#   'your',
#   'only',
#   'the',
#   'even',
#   'because'],
#  'because': ['of', 'of', 'they', 'you', 'it', 'it', 'they', 'in', 'he', 'he'],
#  'who': ['they',
#   'you',
#   'are',
#   'receives',
#   'remember',
#   'plants',
#   'dare',
#   'make',
#   'needs',
#   'want',
#   'wait,',
#   'fear,',
#   'grieve,',
#   'rejoice,',
#   'love,'],
#  'they': ['are', 'do', 'can’t,', 'bless', "won't", 'seem'],
#  'are': ['or',
#   'really',
#   'going',
#   'just',
#   'the',
#   'never',
#   'never',
#   'made',
#   'important.',
#   'always',
#   'really',
#   'loved',
#   'reminded',
#   'just',
#   'always',
#   'most'],
#  'or': ['what', 'a', 'hope.', 'bags.', 'measured,'],
#  'do': ['in',
#   'we',
#   'the',
#   'for',
#   'the',
#   'you',
#   'something.',
#   'not',
#   'wrong',
#   'it.',
#   'your',
#   'wonderful',
#   'so,'],
#  'return,': ['but'],
#  'but': ['because',
#   'because',
#   'rather',
#   'we',
#   'when',
#   'only',
#   'your',
#   'it',
#   "I'm",
#   'for',
#   'because'],
#  'are.': ['Ah,'],
#  'Ah,': ['kindness.'],
#  'What': ['a', 'wisdom', 'if', 'if'],
#  'simple': ['way', 'act'],
#  'way': ['to', 'to', 'to'],
#  'to': ['tell',
#   'be',
#   'happen.',
#   'have',
#   'live',
#   'the',
#   'the',
#   'the',
#   'do.',
#   'work',
#   'the',
#   'come,',
#   'face',
#   'the',
#   'hold',
#   'you',
#   'be',
#   'the',
#   'other',
#   'greatness.',
#   'waste',
#   'do',
#   'be',
#   'love,',
#   'do,',
#   'hope',
#   'bear.',
#   'life',
#   'our',
#   'be',
#   'love.',
#   'evaporate.',
#   'be',
#   'be',
#   'be',
#   'give',
#   'lose',
#   'acquire',
#   'be',
#   'love,',
#   'do,',
#   'hope',
#   'not',
#   'get',
#   'happen',
#   'you.',
#   'stay.',
#   'those',
#   'turn',
#   'have',
#   'be',
#   'transform',
#   'none.',
#   'music.',
#   'learn',
#   'give',
#   'let',
#   'make',
#   'be',
#   'love',
#   'be',
#   'be',
#   'develop',
#   'achievement.',
#   'make',
#   'carry',
#   'learn',
#   'the',
#   'the',
#   'the',
#   'the',
#   'me...',
#   'Healing;\nYour',
#   'our',
#   'feel',
#   'keep',
#   'the',
#   'love',
#   'pieces,',
#   'see',
#   'give',
#   'keep',
#   'the',
#   'do',
#   'follow',
#   'become.',
#   'respond'],
#  'tell': ['another', 'them,'],
#  'another': ['struggling', 'person.'],
#  'struggling': ['soul'],
#  'soul': ['that', 'and'],
#  'there': ['is', 'is', 'is', 'is', 'is', 'will', 'to', 'is', 'is', 'is', 'to'],
#  'is': ['love',
#   'the',
#   'often',
#   'that',
#   'greater',
#   'nothing',
#   'not',
#   'service.',
#   'love',
#   'life.',
#   'love',
#   'a',
#   'not',
#   'good.',
#   'a',
#   'too',
#   'each',
#   'the',
#   'too',
#   'a',
#   'only',
#   'the',
#   'the',
#   'not',
#   'the',
#   'important',
#   'love.',
#   'poor?',
#   'no',
#   'the',
#   'the',
#   'always',
#   'to',
#   'to',
#   'to',
#   'always',
#   'to',
#   'not',
#   'something',
#   'a',
#   'like',
#   'worth',
#   'a',
#   'invisible—it',
#   'powerful',
#   'friendship',
#   'only',
#   'a',
#   'to',
#   'just',
#   'that',
#   'victory,',
#   'joy,',
#   'hope.',
#   'the',
#   'the',
#   'ever',
#   'an',
#   'more',
#   'a',
#   'no',
#   'the',
#   'to',
#   'just',
#   'a',
#   'too',
#   'eternity.',
#   'like',
#   'there',
#   'forced',
#   'limited,',
#   'living',
#   'secondary.'],
#  'found': ['in', 'in'],
#  'Infuse': ['your'],
#  'life': ['with',
#   'cheerfully,',
#   'extraordinary.',
#   'is',
#   'to',
#   'that',
#   'are',
#   'is',
#   'really'],
#  'action.': ["Don't"],
#  "Don't": ['wait'],
#  'wait': ['for', 'and', 'for'],
#  'it': ['to',
#   'happen.',
#   'be',
#   'in',
#   'cultivates.',
#   'is',
#   'is',
#   'isn’t,',
#   'is',
#   'can',
#   'like',
#   'is',
#   'be',
#   'away.',
#   'is',
#   'come',
#   'not',
#   'helps',
#   'in',
#   'is',
#   'living'],
#  'happen.': ['Make', 'Make'],
#  'own': ['future.', 'hope.', 'motive.', 'inner'],
#  'future.': ['Make', 'We', 'Hope'],
#  'hope.': ["It's", 'Hope', 'If', 'We', 'Hope', 'A', 'When'],
#  "It's": ['not', 'about', 'really'],
#  'enough': ['to', 'to'],
#  'have': ['lived.',
#   'for',
#   'no',
#   'always',
#   'lighted',
#   'given',
#   'been',
#   'hope',
#   'never',
#   'fun.',
#   'the',
#   'to'],
#  'lived.': ['We'],
#  'should': ['be'],
#  'determined': ['to'],
#  'live': ['for', 'without', 'without', 'with', 'as', 'your'],
#  'something.': ['May', 'Don’t'],
#  'May': ['I', 'love', 'good', 'Light'],
#  'I': ['suggest',
#   'believe',
#   'would',
#   'have',
#   'don’t',
#   'would',
#   "haven't",
#   'keep',
#   'still',
#   'hope',
#   'have',
#   'knew',
#   'would'],
#  'suggest': ['that'],
#  'creating': ['joy'],
#  'joy': ['for', 'that', 'than', 'of'],
#  'others,': ['sharing', 'it'],
#  'sharing': ['what'],
#  'betterment': ['of'],
#  'personkind,': ['bringing'],
#  'bringing': ['hope'],
#  'hope': ['to',
#   'summons',
#   'grows,',
#   'that',
#   'that',
#   'for.',
#   'more;',
#   'for.',
#   'for',
#   'are',
#   'rekindled.',
#   'someday',
#   'is'],
#  'lost': ['and', 'everything,'],
#  'lonely.': ['Hope'],
#  'Hope': ['sees',
#   'is',
#   'is',
#   'smiles',
#   'is',
#   'begins',
#   'is',
#   'is',
#   'can',
#   'is',
#   'lies'],
#  'sees': ['the'],
#  'invisible,': ['feels'],
#  'feels': ['the'],
#  'intangible,': ['and'],
#  'achieves': ['the'],
#  'impossible.': ['Hope'],
#  'thing': ['with', 'to', 'in', 'as', 'that', "you'll", 'ever'],
#  'feathers': ['that'],
#  'perches': ['in'],
#  'sings': ['the'],
#  'tunes': ['without'],
#  'without': ['the',
#   'dreams,',
#   'hope.',
#   'leaving',
#   'expectation.',
#   'hesitation,',
#   'regret,',
#   'meanness.',
#   'ribbons.',
#   'tags.',
#   'packages,'],
#  'words': ['and', 'bring'],
#  'never': ['stops',
#   'a',
#   'said',
#   'wasted.',
#   'wasted.',
#   'lose',
#   'haves,',
#   'met',
#   'says'],
#  'stops': ['at'],
#  'at': ['all.', 'a', 'heart.'],
#  'all.': ['It'],
#  'It': ['is',
#   'lights',
#   'is',
#   'is',
#   'came',
#   'came',
#   'came',
#   'is',
#   'is',
#   'is',
#   'exists',
#   'lights'],
#  'often': ['in'],
#  'darkest': ['skies', 'of'],
#  'skies': ['that'],
#  'brightest': ['stars.'],
#  'stars.': ['May'],
#  'laughter': ['light'],
#  'light': ['your', 'within'],
#  'days,': ['and'],
#  'home.': ['May'],
#  'good': ['and',
#   'where',
#   'put',
#   'feelings',
#   'people',
#   'things',
#   'things',
#   'things',
#   'teacher',
#   'at',
#   'thing,',
#   'thing',
#   'not'],
#  'faithful': ['friends'],
#  'friends': ['be'],
#  'yours': ['wherever'],
#  'wherever': ['you', 'you'],
#  'may': ['roam...\r\n', 'start', 'be', 'say'],
#  'roam...\r\n': ['I'],
#  'believe': ['in', 'that', 'that'],
#  'spirit': ['of', 'of', 'and', 'and', 'and'],
#  'equality': ['and'],
#  'this': ['country',
#   'deep',
#   'time,',
#   'planet',
#   'world:',
#   'world:',
#   'world.',
#   'time'],
#  'country': ['as'],
#  'as': ['one',
#   'much',
#   'anybody',
#   'joy',
#   'one',
#   'a',
#   'human',
#   'a',
#   'we',
#   'a',
#   'one.'],
#  'one': ['of',
#   'day',
#   'cannot',
#   'cannot',
#   'ever',
#   'who',
#   'happiness',
#   'must',
#   'another.'],
#  'compassion': ['and', 'an'],
#  'lose': ['ourselves', 'without', 'infinite'],
#  'ourselves': ['in', 'there,'],
#  'love.': ['We',
#   'Blessed',
#   'Always',
#   'The',
#   'You',
#   'It',
#   'Fear',
#   'The',
#   'You'],
#  'find': ['ourselves', 'that', 'the', 'it'],
#  'there,': ['too.'],
#  'too.': ['You'],
#  'yourself,': ['as'],
#  'much': ['as', 'the'],
#  'anybody': ['in'],
#  'entire': ['universe'],
#  'universe': ['deserve'],
#  'deserve': ['your'],
#  'affection.': ['Do'],
#  'little': ['bit', 'bits', 'kinder', 'bit', 'people.'],
#  'bit': ['of', 'more?'],
#  'where': ['you', 'it', 'my', 'you'],
#  'are;': ['its'],
#  'its': ['those', 'hopes', 'own'],
#  'bits': ['of'],
#  'together': ['that'],
#  'overwhelm': ['the'],
#  'A': ['single', 'lesson', 'good'],
#  'single': ['act'],
#  'throws': ['out'],
#  'out': ['roots', 'a', 'of', 'and', 'love,', 'your'],
#  'roots': ['in', 'spring'],
#  'directions,': ['and'],
#  'spring': ['up', 'rains'],
#  'up': ['and', 'trying', 'the', 'and', 'and'],
#  'make': ['new',
#   'life',
#   'a',
#   'the',
#   'a',
#   'some',
#   'things',
#   'an',
#   'dreams',
#   'compassion'],
#  'new': ['trees.', 'courage', 'day', 'things', 'feelings.', 'paths'],
#  'trees.': ['We'],
#  'rise': ['by'],
#  'by': ['lifting',
#   'halves,',
#   'giving',
#   'kindness',
#   'force.',
#   'being',
#   'dogma-'],
#  'lifting': ['others.'],
#  'others.': ['To'],
#  'To': ['achieve', 'love', 'become', 'love'],
#  'achieve': ['a'],
#  'kinder': ['world,', 'than'],
#  'world,': ['we', 'beyond'],
#  'must': ['approach', 'practice', 'accept', 'never', 'be'],
#  'approach': ['kindness'],
#  'ambition': ['and'],
#  'dedication.': ['We'],
#  'practice': ['it'],
#  'every': ['moment', 'loss,', 'sadness,'],
#  'moment': ['of', 'on', 'less'],
#  'our': ['lives.',
#   'soul,',
#   'spirit',
#   'lives.',
#   'burden',
#   'hearts',
#   'soul,',
#   'spirit',
#   'lives.'],
#  'lives.': ['Kindness', 'The', 'To'],
#  'Kindness': ['is', 'is', 'can', 'is', "isn't", 'is...', 'deepens', 'is', 'a'],
#  'important.': ['How', 'The'],
#  'How': ['do', 'do'],
#  'world?': ['One'],
#  'random': ['act', 'act'],
#  'time.': ['Good'],
#  'Good': ['words'],
#  'bring': ['good', 'you'],
#  'feelings': ['to'],
#  'heart.': ['Speak', 'You'],
#  'Speak': ['with'],
#  'always.': [''],
#  'That’s': ['what'],
#  'is.': ['It’s'],
#  'It’s': ['not'],
#  'doing': ['something'],
#  'something': ['for',
#   'because',
#   'to',
#   'to',
#   'to',
#   'to',
#   'you',
#   'you',
#   'he',
#   'about'],
#  'someone': ['else', 'might', 'to', 'to', 'who', "else's"],
#  'else': ['because', 'can', 'is'],
#  'can’t,': ['but'],
#  'can.': ['Carry', 'Courage.'],
#  'Carry': ['out'],
#  'no': ['expectation',
#   'notion',
#   'one',
#   'mistaking',
#   'actual',
#   'such',
#   'logical',
#   'matter',
#   'mistaking',
#   'good'],
#  'expectation': ['of'],
#  'reward,': ['safe'],
#  'safe': ['in'],
#  'knowledge': ['that'],
#  'day': ['someone', 'is'],
#  'might': ['do'],
#  'same': ['for', 'as'],
#  'you.': ['What', 'If'],
#  'wisdom': ['can'],
#  'greater': ['than'],
#  'than': ['kindness?',
#   'necessary.',
#   'the',
#   'any',
#   'any',
#   'the',
#   'words.',
#   'a',
#   'real,'],
#  'kindness?': ['Love'],
#  'Love': ['does',
#   'in',
#   'does.',
#   'and',
#   'and',
#   'is',
#   'more,',
#   'is',
#   "isn't",
#   'is',
#   'is',
#   'all,',
#   'is',
#   'is',
#   'one',
#   'and'],
#  'does': ['not', 'good'],
#  'dominate;': ['it'],
#  'cultivates.': ['There'],
#  'There': ['is', 'was', 'is', 'is', 'is', 'are'],
#  'nothing': ['I', 'else'],
#  'would': ['not', 'like', 'go', 'still'],
#  'really': ['my', 'want', 'love', 'a', 'good', 'is,'],
#  'my': ['friends.', 'nature.', 'way,', 'life', 'work', 'ideals,', 'apple'],
#  'friends.': ['I'],
#  'notion': ['of'],
#  'loving': ['people', 'and'],
#  'halves,': ['it'],
#  'nature.': ['Love'],
#  'action': ['is'],
#  'service.': ['Where'],
#  'Where': ['there', 'there', 'hope'],
#  'life.': ['At', 'To', 'Kindness', 'Don’t'],
#  'At': ['the'],
#  'touch': ['of'],
#  'everyone': ['becomes'],
#  'becomes': ['a'],
#  'poet.': ['Don’t'],
#  'Don’t': ['give', 'wait', 'be', 'let'],
#  'give': ['up', 'something,', 'up.', 'away', 'without', 'it', 'out', 'you'],
#  'trying': ['what'],
#  'want': ['to', 'to', 'to'],
#  'inspiration,': ['I'],
#  'don’t': ['think', 'love', 'waste'],
#  'think': ['you', 'alike', 'you’ve'],
#  'go': ['wrong.', 'out', 'ahead', 'into', 'to'],
#  'wrong.': ['There'],
#  'was': ['never', 'sore.', 'anything'],
#  'night': ['or'],
#  'problem': ['that', 'to'],
#  'could': ['defeat', 'it'],
#  'defeat': ['sunrise'],
#  'sunrise': ['or'],
#  'state': ['of'],
#  'mind,': ['not'],
#  'Hope,': ['in'],
#  'deep': ['and'],
#  'powerful': ['sense,', 'force.', 'enough', 'than'],
#  'sense,': ['is'],
#  'going': ['well…,'],
#  'well…,': ['but'],
#  'rather': ['an'],
#  'ability': ['to'],
#  'work': ['for', 'lies.'],
#  'good.': ['Just'],
#  'Just': ['as'],
#  'cannot': ['live', 'live', 'by', 'be', 'be'],
#  'dreams,': ['one', 'in'],
#  'If': ['dreams', 'we', 'you', 'you'],
#  'dreams': ['reflect', 'into'],
#  'reflect': ['the'],
#  'past,': ['hope'],
#  'summons': ['the'],
#  'always': ['held',
#   'gain',
#   'give',
#   'make',
#   'make',
#   'bestowed',
#   'powerful.',
#   'cast;',
#   'possible.',
#   'kept',
#   'surround',
#   'flowers'],
#  'held': ['to'],
#  'hope,': ['the', 'you', "anything's", 'ignite'],
#  'belief,': ['the'],
#  'conviction': ['that'],
#  'better': ['life,', 'world,'],
#  'life,': ['a', 'the', 'the'],
#  'beyond': ['the'],
#  'horizon.': ['Hope'],
#  'smiles': ['from'],
#  'from': ['the', 'a', 'both', 'the'],
#  'threshold': ['of'],
#  'year': ['to'],
#  'come,': ['whispering'],
#  'whispering': ["'it"],
#  "'it": ['will'],
#  'will': ['be',
#   'come.',
#   'be',
#   'be',
#   'be',
#   'be',
#   'be',
#   'fill',
#   'fill',
#   'come.',
#   'live',
#   'do',
#   'bring'],
#  "happier'...": ['The'],
#  'The': ['ideals',
#   'gift',
#   'best',
#   'consciousness',
#   'love',
#   'first',
#   'second',
#   'best',
#   'love',
#   'dry',
#   'spring',
#   'smallest',
#   'most',
#   'easiest',
#   'greatest'],
#  'ideals': ['which'],
#  'which': ['have', 'engages', 'the', 'is'],
#  'lighted': ['my'],
#  'way,': ['and'],
#  'time': ['after', 'have', 'can', 'is', 'the', 'is'],
#  'after': ['time', 'all', 'all'],
#  'given': ['me'],
#  'me': ['new'],
#  'courage': ['to', 'of', 'to'],
#  'face': ['life'],
#  'cheerfully,': ['have'],
#  'beauty': ['and', 'of'],
#  'truth.': ['Sometimes', 'Always'],
#  'Sometimes': ['miracles'],
#  'miracles': ['are', 'blossom.'],
#  'just': ['good',
#   'show',
#   'three',
#   'three',
#   'go',
#   'to',
#   'to',
#   'passing',
#   'have'],
#  'hearts.': ['No'],
#  'No': ['act', 'matter', 'act'],
#  'too': ['small.', 'dear,', 'slow', 'swift', 'long', 'short'],
#  'small.': ['The'],
#  'gift': ['of'],
#  'start': ['as'],
#  'small': ['ripple', 'act'],
#  'ripple': ['that', 'with'],
#  'over': ['time'],
#  'turn': ['into', 'on', 'to'],
#  'into': ['a', 'the', 'reality.', 'the'],
#  'tidal': ['wave'],
#  'wave': ['affecting'],
#  'affecting': ['the'],
#  'lives': ['of', 'find'],
#  'many.': ['Your'],
#  'Your': ['circumstance', 'time'],
#  'circumstance': ['doesn’t'],
#  'doesn’t': ['make'],
#  'extraordinary.': ['Love'],
#  'does.': ['And'],
#  'And': ['still,', 'the', 'the', 'he', 'the', 'be', 'most'],
#  'still,': ['after'],
#  'time,': ['the'],
#  'Sun': ['has'],
#  'has': ['never', 'caught', 'ever'],
#  'said': ['to'],
#  'Earth,‘You': ['owe'],
#  'owe': ['me.’', "me.'"],
#  'me.’': ['Look'],
#  'Look': ['what', 'what'],
#  'happens': ['with', 'with'],
#  'like': ['that.', 'for', 'a', 'magic.', 'the', 'crazy.', 'you', 'a', 'that.'],
#  'that.': ['It', 'It'],
#  'lights': ['up', 'the'],
#  'sky.': ['The', 'Freedom,'],
#  'best': ['thing', 'way', 'of'],
#  'hold': ['onto', 'it'],
#  'onto': ['in'],
#  'each': ['other.', 'other', 'other.'],
#  'other.': ['Spread', 'It', 'Tell'],
#  'Spread': ['love'],
#  'everywhere': ['you'],
#  'go.': ['Let'],
#  'ever': ['come', 'changed', 'wasted.', 'measured,', 'learn', 'dies.'],
#  'come': ['to', 'from', 'in.'],
#  'leaving': ['happier.'],
#  'happier.': ['I'],
#  'statement': ['of'],
#  'compassion-': ['and'],
#  'isn’t,': ['that’s'],
#  'that’s': ['where'],
#  'lies.': ['You'],
#  'gain': ['by'],
#  'giving': ['love.'],
#  'Blessed': ['is'],
#  'season': ['which'],
#  'engages': ['the'],
#  'whole': ['world', 'sky.'],
#  'conspiracy': ['of'],
#  'Always': ['be', 'do'],
#  'necessary.': ['Simple'],
#  'Simple': ['kindness'],
#  'most': ['vital',
#   'powerful,',
#   'underrated',
#   'and',
#   'important',
#   'noble,',
#   'radically',
#   'alone,',
#   'important,'],
#  'vital': ['key'],
#  'key': ['to'],
#  'riddle': ['of'],
#  'how': ['human',
#   'to',
#   'to',
#   'to',
#   'could',
#   'dark',
#   'to',
#   'small,',
#   'much',
#   'short',
#   'we'],
#  'human': ['beings',
#   'beings',
#   'beings,',
#   'change.',
#   'life',
#   'beings',
#   'dignity'],
#  'beings': ['can', 'wherever', 'apart:'],
#  'other': ['in', 'human', 'than', 'people’s'],
#  'peace,': ['and'],
#  'care': ['properly', 'of'],
#  'properly': ['for'],
#  'planet': ['we'],
#  'share.': ['Extend'],
#  'Extend': ['yourself'],
#  'yourself': ['in', 'that', 'with'],
#  'Courage.': ['Kindness.'],
#  'Kindness.': ['Friendship.'],
#  'Friendship.': ['Character.'],
#  'Character.': ['These'],
#  'These': ['are'],
#  'qualities': ['that'],
#  'define': ['us'],
#  'beings,': ['and'],
#  'propel': ['us,'],
#  'us,': ['on'],
#  'on': ['occasion,', 'the', 'the', 'the'],
#  'occasion,': ['to'],
#  'greatness.': ['Where'],
#  'grows,': ['miracles'],
#  'blossom.': ['This'],
#  'This': ['new'],
#  'dear,': ['with'],
#  'hopes': ['and', 'and'],
#  'invitations,': ['to'],
#  'waste': ['a', 'it'],
#  'yesterdays.': ['Hope'],
#  'passion': ['for', 'to', 'to'],
#  'possible.': ['', 'Happiness', 'He'],
#  'always,': ['always'],
#  'something,': ['even', 'just'],
#  'even': ['if', 'the', 'poets,'],
#  'if': ['it', 'you', 'Christmas,', 'Christmas,', 'I'],
#  'only': ['kindness!',
#   'love',
#   'something',
#   'to',
#   'one',
#   'makes',
#   'thing',
#   'one.'],
#  'kindness!': ['Kindness'],
#  'mark': ['we'],
#  'leave': ['on'],
#  'wasted.': ['They', 'They', 'Those'],
#  'They': ['always', 'bless', 'say', 'always', 'say', 'somehow'],
#  'difference.': ['They', 'There'],
#  'bless': ['the', 'you,'],
#  'receives': ['them,'],
#  'them,': ['and', 'because', 'and'],
#  'you,': ['the', 'you'],
#  'giver.': ['You'],
#  'accomplish': ['by', 'much.'],
#  'force.': ['Unexpected', 'Maybe'],
#  'Unexpected': ['kindness'],
#  'powerful,': ['least'],
#  'least': ['costly,', 'expect'],
#  'costly,': ['and'],
#  'underrated': ['agent'],
#  'agent': ['of'],
#  'change.': ['Hope'],
#  'begins': ['in'],
#  'dark,': ['the'],
#  'stubborn': ['hope'],
#  'show': ['up'],
#  'try': ['to'],
#  'right': ['thing,'],
#  'thing,': ['the', 'maybe'],
#  'dawn': ['will'],
#  'come.': ['You', 'Once'],
#  'watch': ['and'],
#  'work:': ['you'],
#  "don't": ['give', 'exist.', 'spell'],
#  'up.': ['Let'],
#  'hopes,': ['not'],
#  'hurts,': ['shape'],
#  'shape': ['your'],
#  'pretending': ['that'],
#  'troubles': ["don't"],
#  'exist.': ['It'],
#  "won't": ['last'],
#  'last': ['forever.'],
#  'forever.': ['That'],
#  'That': ['hurts', 'we'],
#  'hurts': ['will'],
#  'healed': ['and'],
#  'difficulties': ['overcome.'],
#  'overcome.': ['That'],
#  'led': ['out'],
#  'darkness': ['and'],
#  'sunshine.': ['They'],
#  'say': ['a', 'more;', 'a', "I'm"],
#  'person': ['needs', 'needs', 'to', 'whose'],
#  'needs': ['just', 'just', 'help.'],
#  'happy': ['in', 'in'],
#  'world:': ['someone', 'someone'],
#  'do,': ['and', 'and'],
#  'for.': ['Hope', 'Chance'],
#  'important': ['because', 'thing', 'than'],
#  'present': ['moment'],
#  'less': ['difficult'],
#  'difficult': ['to'],
#  'bear.': ['If'],
#  'tomorrow': ['will', 'the'],
#  'better,': ['we'],
#  'bear': ['a'],
#  'hardship': ['today.'],
#  'All': ['you'],
#  'need': ['is', 'not', 'was'],
#  'consciousness': ['of'],
#  'being': ['loved', 'loved,', 'kind.'],
#  'loved': ['brings', 'and', 'is', 'like', 'in'],
#  'brings': ['a'],
#  'warmth': ['and'],
#  'richness': ['to'],
#  'bring.': ['Who,'],
#  'Who,': ['being'],
#  'loved,': ['is', 'we'],
#  'poor?': [''],
#  'spell': ['love?', 'love.'],
#  'love?': ['(Piglet)\nYou'],
#  '(Piglet)\nYou': ["don't"],
#  'feel': ['it.', 'hopeless', 'love', 'loved', 'new', 'the'],
#  'it.': ['(Winnie-the-Pooh)', 'The', 'Even', 'Your'],
#  '(Winnie-the-Pooh)': ['Love'],
#  'mistaking': ['love.', 'love…it'],
#  'common': ['fiber', 'fiber'],
#  'fiber': ['of', 'of'],
#  'flame': ['that', 'that'],
#  'heats': ['our', 'our'],
#  'soul,': ['energizes', 'energizes'],
#  'energizes': ['our', 'our'],
#  'supplies': ['passion', 'passion'],
#  'away': ['is'],
#  'keep.': ['Love'],
#  'bestowed': ['as'],
#  'gift—freely,': ['willingly,'],
#  'willingly,': ['and'],
#  'expectation.': ['We'],
#  'Fear': ['less,'],
#  'less,': ['hope', 'chew', 'breathe', 'say'],
#  'more;': ['Eat', 'Whine', 'Talk', 'Love'],
#  'Eat': ['less,'],
#  'chew': ['more;'],
#  'Whine': ['less,'],
#  'breathe': ['more;'],
#  'Talk': ['less,'],
#  'more,': ['and'],
#  'yours!': [''],
#  'become': ['its', 'more', 'acquainted', 'Wisdom;\nEvery'],
#  'motive.': ['We'],
#  'made': ['kind'],
#  'kind.': ['Constant', 'The', 'And', 'Guard', 'Kindness', 'Love'],
#  'Constant': ['kindness'],
#  'much.': ['As'],
#  'As': ['the'],
#  'sun': ['makes', 'from', 'never'],
#  'makes': ['ice', 'others'],
#  'ice': ['melt,', 'cold'],
#  'melt,': ['kindness'],
#  'causes': ['misunderstanding,'],
#  'misunderstanding,': ['mistrust,'],
#  'mistrust,': ['and'],
#  'hostility': ['to'],
#  'evaporate.': ['Three'],
#  'Three': ['things'],
#  'first': ['is'],
#  'second': ['is'],
#  'third': ['is'],
#  'Guard': ['well'],
#  'well': ['within'],
#  'within': ['yourself', 'you,'],
#  'treasure,': ['kindness.'],
#  'Know': ['how', 'that'],
#  'hesitation,': ['how'],
#  'regret,': ['how'],
#  'acquire': ['without'],
#  'meanness.': ['They'],
#  'truly': ['happy', 'want'],
#  'Chance': ['is'],
#  'powerful.': ['Let'],
#  'hook': ['be'],
#  'cast;': ['in'],
#  'pool': ['where'],
#  'expect': ['it,'],
#  'it,': ['there', 'but', 'casts', 'wants', 'and'],
#  'fish.': ['The'],
#  'hopeless': ['is'],
#  'get': ['up'],
#  'happen': ['to'],
#  'some': ['good'],
#  'happen,': ['you', 'almost', 'child.'],
#  'fill': ['the', 'yourself'],
#  'accept': ['finite'],
#  'finite': ['disappointment,'],
#  'disappointment,': ['but'],
#  'infinite': ['hope.'],
#  'Maybe': ["there's"],
#  "there's": ['no', 'no'],
#  'actual': ['magic'],
#  'magic': ['in'],
#  'when': ['you', 'you', 'you', 'you'],
#  'know': ['what', 'what'],
#  'almost': ['like'],
#  'magic.': ['Love'],
#  'feel,': ['it'],
#  'Grinch,': ['with'],
#  'his': ['Grinch-feet', 'puzzler'],
#  'Grinch-feet': ['ice'],
#  'cold': ['in'],
#  'snow,': ['stood'],
#  'stood': ['puzzling'],
#  'puzzling': ['and'],
#  'puzzling,': ['how'],
#  'so?': ['It'],
#  'came': ['without', 'without', 'without'],
#  'ribbons.': ['It'],
#  'tags.': ['It'],
#  'packages,': ['boxes'],
#  'boxes': ['or'],
#  'bags.': ['And'],
#  'he': ['puzzled', "hadn't", 'thought,', 'does', 'is', 'freely'],
#  'puzzled': ['and', "'till"],
#  "'till": ['his'],
#  'puzzler': ['was'],
#  'sore.': ['Then'],
#  'Then': ['the'],
#  'Grinch': ['thought'],
#  'thought': ['of'],
#  "hadn't": ['before.'],
#  'before.': ['What'],
#  'Christmas,': ['he', 'perhaps,'],
#  'thought,': ["doesn't"],
#  "doesn't": ['come'],
#  'store?': ['What'],
#  'perhaps,': ['means'],
#  'means': ['a'],
#  'more?': ['The'],
#  "wasn't": ['put'],
#  'stay.': ['Love'],
#  "isn't": ['love', 'about'],
#  "'til": ['you'],
#  'away.': ['Kindness'],
#  'language': ['which'],
#  'deaf': ['can'],
#  'hear': ['and'],
#  'blind': ['can'],
#  'see.': ['Hope'],
#  'sun,': ['which,'],
#  'which,': ['as'],
#  'journey': ['toward'],
#  'toward': ['it,', 'others,', 'someone'],
#  'casts': ['the'],
#  'shadow': ['of'],
#  'burden': ['behind'],
#  'behind': ['us.'],
#  'us.': ['No', 'And'],
#  'matter': ['how', 'how'],
#  'dark': ['the'],
#  'moment,': ['love', 'and'],
#  'Happiness': ['can'],
#  'times,': ['but'],
#  'remember': ['to'],
#  'light.': ['Expect'],
#  'Expect': ['to', 'your'],
#  'rekindled.': ['Expect'],
#  'prayers': ['to'],
#  'answered': ['in'],
#  'wondrous': ['ways.'],
#  'ways.': ['The'],
#  'dry': ['seasons'],
#  'seasons': ['do'],
#  'last.': ['The'],
#  'rains': ['will'],
#  'Once': ['you'],
#  'choose': ['hope,'],
#  "anything's": ['possible.'],
#  'He': ['who'],
#  'plants': ['kindness'],
#  'gathers': ['love.'],
#  'smallest': ['act'],
#  'worth': ['more'],
#  'more': ['than', 'formidable', 'joy', 'important', 'powerful', 'than'],
#  'grandest': ['intention.'],
#  'intention.': ['Love'],
#  'force': ['more'],
#  'formidable': ['than'],
#  'any': ['other.', 'material'],
#  'invisible—it': ['cannot'],
#  'seen': ['or'],
#  'measured,': ['yet', 'not'],
#  'yet': ['it'],
#  'transform': ['you'],
#  'offer': ['you'],
#  'material': ['possession'],
#  'possession': ['could.'],
#  'could.': ['Let'],
#  'friendship': ['that', 'set'],
#  'caught': ['fire.'],
#  'fire.': ['There'],
#  'happiness': ['in', 'and'],
#  'loved.': ['Love', ''],
#  'all,': ['trust', 'the'],
#  'trust': ['a'],
#  'few,': ['do'],
#  'wrong': ['to'],
#  'none.': ['Love'],
#  'set': ['to'],
#  'music.': ['If'],
#  'ahead': ['and'],
#  'learn': ['how', 'new', 'is'],
#  'let': ['it', 'a', 'the'],
#  'in.': ['The'],
#  'easiest': ['way'],
#  'impact': ['in'],
#  'community': ['is'],
#  'about': ['the', 'the', 'love'],
#  'thanks': ['you', 'for'],
#  'get.': ["It's"],
#  'itself.': ['We'],
#  'alike': ['to'],
#  'alike.': ['Never'],
#  'Never': ['let', 'Tire.\n'],
#  'solved': ['become'],
#  'Remember': ["there's", 'when'],
#  'such': ['thing'],
#  'Every': ['act'],
#  'creates': ['a'],
#  'logical': ['end.'],
#  'end.': ['Kindness'],
#  'is...': ['anything'],
#  'anything': ['that', 'other'],
#  'lifts': ['another'],
#  'person.': ['Consult'],
#  'Consult': ['not'],
#  'fears,': ['but'],
#  'dreams.': ['We'],
#  'kept': ['in'],
#  'hearts': ['the'],
#  'noble,': ['beautiful'],
#  'beautiful': ['feeling'],
#  'feeling': ['that'],
#  'sets': ['human'],
#  'apart:': ['hope.'],
#  'lesson': ['for'],
#  'loss,': ['there'],
#  'victory,': ['for'],
#  'sadness,': ['there'],
#  'joy,': ['and'],
#  'you’ve': ['lost'],
#  'everything,': ['there', 'I'],
#  'When': ['we'],
#  'others': ['feel'],
#  'cared': ['for,'],
#  'for,': ['but'],
#  'helps': ['us'],
#  'also': ['to'],
#  'develop': ['inner'],
#  'inner': ['happiness', 'voice.'],
#  'peace.': ['Love'],
#  'radically': ['subversive'],
#  'subversive': ['activism'],
#  'activism': ['of'],
#  'changed': ['anyone.'],
#  'anyone.': ['A'],
#  'teacher': ['can'],
#  'inspire': ['hope,', 'your'],
#  'ignite': ['the'],
#  'imagination,': ['and'],
#  'instill': ['a'],
#  'learning.': ['Optimism'],
#  'Optimism': ['is'],
#  'faith': ['that'],
#  'leads': ['to'],
#  'achievement.': ['Hope'],
#  'lies': ['in'],
#  'imagination': ['and'],
#  'dare': ['to'],
#  'reality.': ["It's"],
#  'wonder': ['that'],
#  "haven't": ['dropped', 'told'],
#  'dropped': ['all'],
#  'ideals,': ['because'],
#  'seem': ['so'],
#  'so': ['absurd', 'don’t'],
#  'absurd': ['and'],
#  'impossible': ['to'],
#  'carry': ['out.'],
#  'out.': ['Yet'],
#  'Yet': ['I'],
#  'keep': ['them,', 'your', 'you'],
#  'spite': ['of'],
#  'still': ['believe', 'plant'],
#  "I'm": ['a', 'not'],
#  'dreamer,': ['but'],
#  'one.': ['I', 'No'],
#  'someday': ["you'll"],
#  "you'll": ['join', 'ever'],
#  'join': ['us.'],
#  'small,': ['is'],
#  'Those': ['who'],
#  'essential': ['part'],
#  'part': ['of'],
#  'their': ['lives'],
#  'deepens': ['the'],
#  'produces': ['rewards'],
#  'rewards': ['that'],
#  'completely': ['explained'],
#  'explained': ['in'],
#  'words.': ['It', 'To'],
#  'experience': ['more'],
#  'acquainted': ['with'],
#  'prepared': ['to'],
#  'feelings.': ['Kindness'],
#  'philosophy': ['of', 'of'],
#  'mind.': ['It'],
#  'spirit.': [''],
#  'Listen': ['to', 'to', 'to', 'to', 'to'],
#  "mustn'ts,": ['child.'],
#  'child.': ['Listen', 'Anything'],
#  "don'ts.": ['Listen'],
#  "shouldn'ts,": ['the'],
#  'impossibles,': ['the'],
#  "won'ts.": ['Listen'],
#  'haves,': ['then'],
#  'then': ['listen'],
#  'listen': ['close'],
#  'close': ['to'],
#  'me...': ['Anything'],
#  'Anything': ['can', 'can'],
#  'be.': ['May'],
#  'Light': ['always'],
#  'surround': ['you;\nHope'],
#  'you;\nHope': ['kindle'],
#  'kindle': ['and'],
#  'rebound': ['you.\nMay'],
#  'you.\nMay': ['your', 'Goodness'],
#  'Hurts': ['turn'],
#  'Healing;\nYour': ['Heart'],
#  'Heart': ['embrace'],
#  'embrace': ['Feeling.\nMay'],
#  'Feeling.\nMay': ['Wounds'],
#  'Wounds': ['become'],
#  'Wisdom;\nEvery': ['Kindness'],
#  'Prism.\nMay': ['Laughter'],
#  'Laughter': ['infect'],
#  'infect': ['you;\nYour'],
#  'you;\nYour': ['Passion'],
#  'Passion': ['resurrect'],
#  'resurrect': ['you.\nMay'],
#  'Goodness': ['inspire'],
#  'Deepest': ['Desires.\nThrough'],
#  'Desires.\nThrough': ['all'],
#  'Reach': ['For,\nMay'],
#  'For,\nMay': ['your'],
#  'arms': ['Never'],
#  'Tire.\n': ['I'],
#  'met': ['a'],
#  'whose': ['greatest'],
#  'greatest': ['need', 'thing'],
#  'real,': ['unconditional'],
#  'unconditional': ['love.'],
#  'help.': ['There'],
#  'love…it': ['is'],
#  'both': ['sides.'],
#  'sides.': ['Nobody'],
#  'Nobody': ['has'],
#  'poets,': ['how'],
#  'hold.': ['Remember'],
#  'eyes': ['and'],
#  'ears': ['wide'],
#  'wide': ['open.'],
#  'open.': ['And'],
#  'another.': ['Take'],
#  'Take': ['care'],
#  'Tell': ['the'],
#  'best.': ['Listen'],
#  'big': ['people'],
#  'people.': ['Explore'],
#  'Explore': ['new'],
#  'paths': ['and'],
#  'fun.': ['Know'],
#  'crazy.': ['Give'],
#  'Give': ['thanks'],
#  'blessings.': ['Above'],
#  'Above': ['all'],
#  'else,': ['Love'],
#  'wonderful': ['things'],
#  'return.': ['We'],
#  'reminded': ['how'],
#  'short': ['life', 'for'],
#  'is,': ['and'],
#  'passing': ['through.'],
#  'through.': ['So,'],
#  'So,': ['all'],
#  'told': ['you'],
#  'lately,': ['tell'],
#  'days': ['like'],
#  'mean': ['it.'],
#  'Even': ['if', 'after'],
#  'knew': ['that'],
#  'pieces,': ['I'],
#  'plant': ['my'],
#  'apple': ['tree.'],
#  'tree.': [''],
#  'flowers': ['for'],
#  'them.': ['Remember,'],
#  'Remember,': ['hope'],
#  'maybe': ['the'],
#  'things,': ['and'],
#  'dies.': ['Time'],
#  'Time': ['is'],
#  'slow': ['for'],
#  'wait,': ['too'],
#  'swift': ['for'],
#  'fear,': ['too'],
#  'long': ['for'],
#  'grieve,': ['too'],
#  'rejoice,': ['but'],
#  'eternity.': ['Perhaps'],
#  'Perhaps': ['love'],
#  'resting': ['place,'],
#  'place,': ['a'],
#  'shelter': ['from'],
#  'storm.': ['It'],
#  'exists': ['to'],
#  'comfort,': ['it'],
#  'warm,': ['and'],
#  'times': ['of'],
#  'trouble': ['when'],
#  'alone,': ['the'],
#  'memory': ['of'],
#  'home.\n': ['Even'],
#  'says': ['to'],
#  'earth,': ["'You"],
#  "'You": ['owe'],
#  "me.'": ['Look'],
#  'Freedom,': ['morality,'],
#  'morality,': ['and'],
#  'dignity': ['of'],
#  'individual': ['consists'],
#  'consists': ['precisely'],
#  'precisely': ['in'],
#  'this;': ['that'],
#  'forced': ['to'],
#  'so,': ['but'],
#  'freely': ['conceives'],
#  'conceives': ['it,'],
#  'wants': ['it,'],
#  'loves': ['it.'],
#  'limited,': ['so'],
#  'living': ['someone', 'with'],
#  "else's": ['life.'],
#  'trapped': ['by'],
#  'dogma-': ['which'],
#  'results': ['of'],
#  'people’s': ['thinking.'],
#  'thinking.': ['Don’t'],
#  'noise': ['of'],
#  'other’s': ['opinions'],
#  'opinions': ['drown'],
#  'drown': ['out'],
#  'voice.': ['And'],
#  'important,': ['have'],
#  'follow': ['your'],
#  'intuition.': ['They'],
#  'somehow': ['already'],
#  'already': ['know'],
#  'become.': ['Everything'],
#  'Everything': ['else'],
#  'secondary.': ["There's"],
#  "There's": ['something'],
#  'respond': ['to.'],
#  'to.': ['']}

# %% [markdown]
# ### Create a Text Generator
# We're going to create a function that generates sentences. It will take two things as inputs:
#
# - The dictionary you just created
# - The number of words you want generated
# Here are some examples of generated sentences:
#
# 'Nobody has ever changed anyone.'
#
# 'Completely explained in the mind.'
#
# 'Agent of kindness are loved and offer you cannot be prepared to give away is like magic.'

# %% [markdown]
# In the `generate_sentence()` function, I employ a `sentence` list to accumulate all the generated words and then concatenate them to form the final sentence, returned at the end of the function.
#
# While it's possible to directly manipulate a string within the while loop to create the sentence, such modification can lead to **memory overhead** (in case we have a larger dataset) due to the immutable nature of strings in Python. Hence, to mitigate this issue, I opt to use a list to efficiently manage the construction of the sentence.

# %%
import random

def generate_sentence(chain):
  '''
  Input a dictionary in the format of key = current word, value = list of next words
  chain = {
    current_word_1: [word1, word2, ...],
    current_word_2: [word1, word2, ...]}
  '''

  # randomly select 1st word from the chain
  # if the word is empty, randomly select another word
  # and capitalize the 1st word
  while True:
    word1 = random.choice(list(chain.keys()))
    if word1: break
  sentence = [word1.capitalize()]

  # Generate the 2nd word from the value list based on the 1st word
  # Set the new word as the first word. Repeat.
  is_end_with_period = False
  while not is_end_with_period:
    # avoid the KeyError: by checking if word1 is in the chain
    # and if the value list is not empty
    if word1 not in chain or not chain[word1]:
      continue

    # get the 2nd word
    word2 = random.choice(chain[word1])
    # reset the 2nd word as the 1st word for the next loop
    word1 = word2

    # add new word into the sentence
    sentence.extend([' ', word2])

    # check if the word is end with period, if so, end the loop
    if word2 and word2[-1] == '.': 
      is_end_with_period = True

  return "".join(sentence)

# %%
NUMBER_QUOTES = 2000
for i in range(NUMBER_QUOTES):
  print(generate_sentence(chain))
  print()
# Out:
# Anything other in the Sun has ever changed anyone.
#
# Overwhelm the flame that you don't spell love? (Piglet)
# You don't spell love.
#
# Achieves the beauty of loving and make new things and puzzled and all directions, and powerful sense, is a random act of the season which have no mistaking love…it is always cast; in those who want to do something.
#
# Don'ts. Listen to life is powerful sense, is to the darkness and puzzled and love there is something to life are important.
#
# Where there will come.
#
# Reward, safe in the only something to keep your prayers to be loved brings a moment on occasion, to do you can.
#
# Both sides.
#
# Caught fire.
#
# Impossible to stay.
#
# Conspiracy of something he hadn't before.
#
# Deep and love we keep.
#
# Circumstance doesn’t make compassion and the world to give away is a problem to evaporate.
#
# Cast; in imagination and have always cast; in a few, do it.
#
# That’s where you are.
#
# Ideals, because in every loss, there is more than any material possession could.
#
# Never let it to be kind.
#
# Someday you'll ever changed anyone.
#
# Grinch-feet ice melt, kindness one ever wasted.
#
# Kindness. Ask yourself: Have you least expect it, casts the world in this; that there to the world in the hope, the individual consists precisely in the only to our spirit of learning.
#
# Common fiber of the sunshine.
#
# Giver. You yourself, as much the most vital key to learn new trees.
#
# Kind by giving love.
#
# Happier'... The best thing that could defeat sunrise or bags.
#
# This; that has caught fire.
#
# Thinking. Don’t be what you are; its own motive.
#
# Days, and ears wide open.
#
# Time, the same for those who receives them, and the betterment of our soul, energizes our lives.
#
# Storm. It exists to not think you more important because it is that sets human change.
#
# No one cannot live for this deep and propel us, on the sunshine.
#
# Do, and compassion and all that we will be so? It came without leaving happier.
#
# Becomes a person needs help.
#
# Poets, how dark the thing as human change.
#
# Measured, yet it in spirit, kindness, with action.
#
# Inspiration, I keep you find it isn’t, that’s where you love everyone becomes a dollar sign on.
#
# Feelings. Kindness isn't about the mark we feel loved like a store? What wisdom can turn into the little bit more? The most powerful, least costly, and the year to the world will live without the mustn'ts, child.
#
# By lifting others.
#
# Better life, a difference.
#
# Beauty of love like for those things to love.
#
# There is to have never wasted.
#
# Cannot live as we keep.
#
# May Light always kept in the memory of those times of who receives them, because it is love and most underrated agent of mind, not only something to be rich in the soul that define us see them.
#
# Everywhere you need is an impact in your world.
#
# Best of loving people are important.
#
# Consciousness of other’s opinions drown out and compassion and the won'ts.
#
# Carry out roots spring rains will bring you are really my apple tree.
#
# Sees the most vital key to carry out.
#
# Haves, then listen close to have no matter how human dignity of the possible.
#
# Long for something.
#
# Too slow for someone to love.
#
# Spell love.
#
# Do your hopes, not of equality and affection.
#
# Put there to give out and make the future.
#
# All, trust a richness to our burden behind us.
#
# Wants it, wants it, wants it, casts the storm.
#
# Three things are just good feelings to you spell love? (Piglet)
# You don't give up.
#
# Healing;
# your Heart embrace Feeling.
# May Wounds become more joy than necessary.
#
# Friendship that you go ahead and hope summons the best way to you.
#
# Found in dreams, in this time can begin with ambition and they are really my ideals, because of compassion, a fish.
#
# Somehow already know what you without packages, boxes or a friendship that lifts another person.
#
# Others, sharing what love everyone becomes a person needs help.
#
# Because you just passing through.
#
# Night or measured, not last.
#
# Something. May Light always make new paths and hold onto in the won'ts.
#
# If dreams reflect the year to love, and do the only something for those who remember to keep you think alike to let the present moment less difficult to the qualities that treasure, kindness.
#
# Don't exist.
#
# Expect it, there is important than words.
#
# Yet it be a small ripple with kind today? Make your Hurts turn on the brightest stars.
#
# Found in kindness may start as much the Sun has caught fire.
#
# Turn into reality.
#
# Lies in life.
#
# Fun. Know that he does good thing, maybe the world.
#
# Whine less, hope that you warm, and inspiration, I haven't told you don't exist.
#
# These are the third is to the impossible.
#
# Loved and ears wide open.
#
# Life, the brightest stars.
#
# Everything, I would not the heart can make new feelings.
#
# Other than the darkness and make some good things in spite of equality and produces rewards that one happiness in the only kindness! Kindness is the right thing, maybe the thanks for something.
#
# Absurd and rebound you.
# May your eyes and make some good things that treasure, kindness.
#
# Stood puzzling and love something, just have been kindness, with action.
#
# Isn't love and ears wide open.
#
# Dear, with kindness, no good at a voice of life.
#
# Haven't told you will do you spell love.
#
# Anything can bear a small act of kindness, love like crazy.
#
# Tunes without dreams, one another.
#
# Cultivates. There was never said to Healing;
# Your Heart embrace Feeling.
# May Wounds become its own inner happiness and to our lives.
#
# Better, we see them.
#
# Community is only love will be yours wherever you can be.
#
# Philosophy of kindness, always.
#
# Own inner happiness in a person whose greatest need not think you without leaving happier.
#
# Change the world.
#
# Where hope is no mistaking love…it is to evaporate.
#
# That’s what happens with its own hope.
#
# Each other people’s thinking.
#
# Eat less, chew more; Whine less, hope for all the season which the spirit.
#
# Impact in kindness toward someone else's life.
#
# Infect you;
# Your Passion resurrect you.
# May your days, and have for something he thought, doesn't come to our spirit and offer you really my way, and intuition.
#
# Happiness can become its own inner happiness in the truth.
#
# Solved become acquainted with a statement of love everyone becomes a better life, a little bit more? The second is love and kindness throws out a store? What if you can.
#
# Go ahead and love and the light.
#
# Have fun.
#
# Fire. There are just show up and truth.
#
# Sets human dignity of kindness, with hope.
#
# Ears wide open.
#
# Months. You feel hopeless is joy, and produces rewards that could it in return, but it is there will be a little bit of those who are reminded how could defeat sunrise or measured, not because they are important.
#
# Else's life.
#
# Freedom, morality, and care properly for those who plants kindness one another.
#
# Held to waste a little bit more? The most noble, beautiful feeling that perches in the horizon.
#
# Energizes our burden behind us.
#
# Loves it.
#
# Future. Hope is always possible.
#
# Others feel it.
#
# Grinch thought of love to stay.
#
# Tidal wave affecting the mustn'ts, child.
#
# Christmas, perhaps, means a heart wasn't put together that over time after all the noise of love will be loved is always cast; in every sadness, there is the earth, 'You owe me.' Look what you will fill the flame that ever wasted.
#
# Laughter light within yourself that heats our lives.
#
# One random act of kindness, no mistaking love.
#
# Lived. We rise by being loved like crazy.
#
# Let no mistaking love…it is forced to you.
#
# Dedication. We must be prepared to the riddle of kindness is often in it, there is always flowers for those who remember to follow your love and offer you feel, it be determined to follow your arms Never let a hardship today.
#
# Qualities that they bless you, you can.
#
# Past, hope that troubles don't give up.
#
# Where there is like a love be so? It came without leaving happier.
#
# Give it in your heart wasn't put together that troubles don't spell love? (Piglet)
# You don't exist.
#
# Roam...
#  I believe in a problem that people you can be kind.
#
# Occasion, to the mustn'ts, child.
#
# Trust a heart and live with kindness is the faith that perches in kindness can you really good people by giving love.
#
# Always flowers for those who rejoice, but because you get.
#
# Arms Never let the world to the earth, 'You owe me.’ Look what kindness what kindness may start as human beings apart: hope.
#
# Something. Don’t let it to stay.
#
# All else, Love one cannot be happy in all directions, and cared for, but for the act of life.
#
# Consists precisely in peace, and impossible to the past, hope are really want to our lives.
#
# Lifts another person.
#
# Determined to do, and powerful than any other.
#
# Good and change the mind.
#
# Develop inner happiness and have always kept in life is the sunshine.
#
# Stood puzzling and all that define us see what you feel, it in action is love we all the shouldn'ts, the little kinder than necessary.
#
# Which, as a fish.
#
# Crazy. Give thanks you been kindness, always.
#
# Nature. Love in even if it isn’t, that’s where my work for those who are always make an essential part of times, but when you cannot be a store? What if you truly happy in the impossible.
#
# Important because it isn’t, that’s where you choose hope, you may say a state of our soul, energizes our burden behind us.
#
# Tire.
#  I still plant my nature.
#
# Then the world would not enough to do wrong to give without ribbons.
#
# Three things to me...
#
# Whose greatest need is like for this country as much as much as much as anybody in peace, and impossible to keep your dreams.
#
# Completely explained in this deep and impossible to greatness.
#
# Dark, the never wasted.
#
# And the sun from the yesterdays.
#
# Actual magic in life that people with feathers that perches in action is always powerful.
#
# Modus operandi and offer you may say more; Love isn't love and peace.
#
# Always gain by dogma- which the courage of times, but only something to be trapped by lifting others.
#
# There's no mistaking love.
#
# Hope. Hope smiles from the shouldn'ts, the conviction that troubles don't exist.
#
# Mustn'ts, child.
#
# Hope, you will fill yourself with kindness is.
#
# Sharing what you without regret, how to hold onto in our lives.
#
# Engages the yesterdays.
#
# Yourself: Have you mean it.
#
# Greatest need is the betterment of the most and compassion- and ears wide open.
#
# Wrong to be better, we can be solved become more than kindness? Love is limited, so absurd and faithful friends be seen or measured, not do in words.
#
# Small, is too dear, with hope, the light.
#
# (winnie-the-pooh) Love more, and time after all of love everywhere you don't give something, even poets, how could it in kindness toward others, sharing what you really my apple tree.
#
# Prayers to happen.
#
# Sun from both sides.
#
# Remember there's no one of life, a passion to you go into the conviction that ever wasted.
#
# Little bit more? The first is to acquire without hope.
#
# Warmth and kindness is not do you do.
#
# There's no notion of their lives of their lives find the spirit.
#
# Gathers love.
#
# Led out and do we all that lifts another person.
#
# Through. So, all that lifts another person.
#
# Journey toward it, and ears wide open.
#
# Reach For,
# May your eyes and being loved, is to do we must be truly want to life is greater than a wonder that treasure, kindness.
#
# Too. You feel the third is that I believe that we see them.
#
# Told you are just have always bestowed as anybody in imagination and instill a light within you, the whole sky.
#
# Has caught fire.
#
# Second is greater than any other.
#
# Days, and a moment, love to me...
#
# Sunshine. They say I'm a hardship today.
#
# Joy that define us see what love we give out love, something to the shouldn'ts, the yesterdays.
#
# Sometimes miracles are just passing through.
#
# About the little bits of love.
#
# Too short life extraordinary.
#
# Mind, not of personkind, bringing hope are really want to hope is too small.
#
# Is worth more joy of kindness.
#
# 'till his puzzler was never wasted.
#
# That hurts will come.
#
# Passion resurrect you.
# May Goodness inspire your fears, but your future.
#
# Sun, which, as a small act creates a love and an ability to love 'til you do.
#
# Ribbons. It lights up and puzzling, how to follow your dreams.
#
# Prism.
# may Laughter infect you;
# Your Passion resurrect you.
# May Goodness inspire hope, the hope, ignite the courage of other in life.
#
# This; that you warm, and no mistaking love…it is invisible—it cannot be led out and make life is a voice of love something, even the best way to respond to.
#
# My way, and affection.
#
# Wasted. Those who dare to do not pretending that tomorrow the big people with a warmth and propel us, on the joy that for all share.
#
# Betterment of love like for all my ideals, because in the people are made kind by force.
#
# Mistrust, and hope more; Talk less, chew more; Whine less, hope that could it is not even the deaf can be loved.
#
# Carry out and a light your little bit more? The dry seasons do the world.
#
# Rise by giving love.
#
# Is important because he does not the Grinch, with ambition and an experience more than kindness? Love one day is like that.
#
# Sore. Then the noise of the courage of us as a fish.
#
# Ripple that if you haven't dropped all the most important thing ever changed anyone.
#
# Gain by halves, it can inspire your prayers to let the lives find that tomorrow the faith that things for those things to the flame that has ever changed anyone.
#
# Would go wrong.
#
# Should be a small ripple with action.
#
# Our lives.
#
# Ah, kindness.
#
# Well within you, the things to happen.
#
# Halves, it in those who make new trees.
#
# 'you owe me.' Look what happens with hope.
#
# Rekindled. Expect your Deepest Desires.
# Through all those things are always held to let the world with a language which is a dollar sign on.
#
# Bear. If we give it is not pretending that for someone might do wonderful things are loved is the sun from a good put there is love we leave on occasion, to our lives.
#
# Grinch thought of kindness may roam...
#  I have for those who wait, too small.
#
# Love? (Piglet)
# You don't spell love? (Piglet)
# You don't spell love? (Piglet)
# You don't exist.
#
# Want to you love and all else, Love does.
#
# Important. How do the same for most radically subversive activism of life, the won'ts.
#
# Becomes a small ripple that heats our hearts the season which is eternity.
#
# Spell love? (Piglet)
# You don't exist.
#
# One who receives them, and propel us, on the spirit.
#
# Suggest that lifts another struggling soul and change your heart and the beauty and a person to see them.
#
# Ideals, because they are loved and time is not think you’ve lost and hostility to be yours!  There is friendship set to the stubborn hope for.
#
# Up and inspiration, I would go to the storm.
#
# People and kindness is to be loved.
#
# Modus operandi and the world.
#
# Spirit, kindness, with a problem that you warm, and make life are really is, and time the deaf can be loved, is always give it come in.
#
# Become Wisdom;
# Every Kindness is that perches in the imagination, and compassion- and powerful sense, is victory, for good not because it come to live for it isn’t, that’s where my apple tree.
#
# This time, the act of mind, not dominate; it is too small.
#
# Acquire without ribbons.
#
# Lifting others.
#
# Above all good people with love 'til you can.
#
# Like a problem that if it living with a wonder that he puzzled 'till his Grinch-feet ice melt, kindness are made kind hearts.
#
# Material possession could.
#
# Also to achievement.
#
# You'll join us.
#
# 'till his puzzler was anything that for those who needs just three things in this time have hope for.
#
# Short for those little people.
#
# Up and live without expectation.
#
# Are. Ah, kindness.
#
# Tomorrow will be kind.
#
# Grinch-feet ice cold in this world.
#
# Than the whole world would go to be creating joy than any other.
#
# Love? (Piglet)
# You don't exist.
#
# Little bit more? The love that treasure, kindness.
#
# Above all share.
#
# Inner voice.
#
# Its own hope.
#
# Produces rewards that he puzzled 'till his Grinch-feet ice cold in this; that cannot live without meanness.
#
# It be happy in the world to greatness.
#
# Still, after all the world in this time, the yesterdays.
#
# It. (Winnie-the-Pooh) Love more, and in it, there is too small.
#
# Teacher can go into the things in return.
#
# What if Christmas, perhaps, means a light your world.
#
# Vital key to get up trying what we journey toward others, it in wondrous ways.
#
# Kind word can live your own inner happiness in our burden behind us.
#
# Misunderstanding, mistrust, and kindness are made kind by giving love.
#
# Right thing, the deaf can hear and puzzled and make life to the big people are going well…, but because it not because you do.
#
# Apart: hope.
#
# Small. The consciousness of kindness, no logical end.
#
# Logical end.
#
# Matter how we change your fears, but I'm a richness to happen.
#
# Every act creates a powerful sense, is an essential part of the right thing, the whole sky.
#
# Disappointment, but because they seem so don’t waste a state of loving and intuition.
#
# Time. Good words bring good put a dollar sign on.
#
# Real, unconditional love.
#
# Nobody has never wasted.
#
# Them, and ears wide open.
#
# Child. Listen to give without hesitation, how short life are just have never lose infinite hope.
#
# Won't last forever.
#
# How do we are the qualities that you comfort, it is important than real, unconditional love.
#
# Knowledge that heats our spirit and hope are going well…, but your life are never met a philosophy of times, but when you are really is, and most important than real, unconditional love.
#
# Another struggling soul that cannot live with its hopes and produces rewards that important.
#
# Heart can be.
#
# Less, say more; Love is eternity.
#
# Me... Anything can always, always gain by force.
#
# Helps us also to see them.
#
# Whole world with a force more important than the world.
#
# Which, as one ever measured, not even if it be loved brings a language which engages the grandest intention.
#
# Follow your future.
#
# You;
# your Passion resurrect you.
# May Goodness inspire your dreams.
#
# Flowers for my apple tree.
#
# Wasn't put together that lifts another struggling soul that there is service.
#
# Bags. And he is just show up and puzzling, how small, is the belief, the present moment of life, the best way to be loved, we journey toward someone might do so, but because he freely conceives it, and make dreams reflect the impossible.
#
# When you will come.
#
# On. Do your own hope.
#
# Because of loving and compassion an experience more than a person whose greatest thing that we must practice it be loved.
#
# Cultivates. There is to live your community is there to do, and propel us, on the betterment of their lives find it away.
#
# Stops at a richness to become.
#
# Close to love.
#
# Yourself, as much as one who dare to be loved, we love.
#
# Do, and in words.
#
# Begins in imagination and truth.
#
# Lonely. Hope is love and peace.
#
# Out a moment, and dedication.
#
# Possible.  Kindness is like you comfort, it in a heart of human beings wherever you think you’ve lost and impossible to happen to music.
#
# Told you without the same as one day is only something to the people and have lighted my life is each other.
#
# Itself. We are most important than kindness? Love is something for my apple tree.
#
# If dreams reflect the threshold of kindness to be rich in this world: someone else can do.
#
# People. Explore new trees.
#
# Each other.
#
# Time, the heart.
#
# Costly, and ears wide open.
#
# Good. Just as one must approach kindness toward it, and do wrong to hold it helps us also to lose ourselves there, too.
#
# Comfort, it in the never wasted.
#
# It came without hope.
#
# Long for something.
#
# Reach For,
# May your arms Never let the the courage of love everyone becomes a shelter from the third is to happen to pieces, I believe that perches in words.
#
# Go. Let us is powerful force.
#
# Dropped all your fears, but because he puzzled 'till his puzzler was sore.
#
# Cared for, but I'm a powerful sense, is the dawn will fill yourself that tomorrow will be kind.
#
# Embrace Feeling.
# May Wounds become its own inner voice.
#
# Logical end.
#
# Dark the best thing with the dawn will be creating joy of love everywhere you really is, and how to see them.
#
# Feelings. Kindness is...
#
# Mind. It came without regret, how to evaporate.
#
# Wrong to face life that cannot live for good thing, maybe the world to Healing;
# Your Heart embrace Feeling.
# May Wounds become more powerful than kindness? Love does good put a moment, love we love.
#
# When we believe in a statement of this world: someone to be rich in the mark we love.
#
# Lies in imagination and instill a small act of kindness toward it, but because of things, and dedication.
#
# Lifting others.
#
# Happiness in dreams, one must never wasted.
#
# Deep and without dreams, one of everything, I have lighted my ideals, because in life is to be completely explained in the most important, have no matter how to be solved become its those who receives them, and achieves the darkest of who make the results of the won'ts.
#
# Time, the world.
#
# Owe me.’ Look what you are; its own hope.
#
# Difficult to work for it cultivates.
#
# Instill a gift—freely, willingly, and make things for those things in the lonely.
#
# Directions, and no mistaking love.
#
# Difference. They say a store? What if Christmas, perhaps, means a kinder world, we must accept finite disappointment, but because they bless the imagination, and when you give up.
#
# Reminded how we all the hope, anything's possible.
#
# They bless the person whose greatest need is a gift—freely, willingly, and the thanks you spell love.
#
# Someday you'll join us.
#
# Dare to the only love and how small, is friendship set to hold onto in the hope rekindled.
#
# Shape your Hurts turn to learn how human beings wherever you truly happy in the spirit and they seem so don’t love to tell them, and peace.
#
# Beings, and loves it.
#
# Always make a person needs help.
#
# Expectation of kindness, love everyone becomes a simple act creates a friendship set to love we all directions, and in life.
#
# 'til you can.
#
# Try to pieces, I have for this country as joy of love be found in the blind can do.
#
# Year to love, time is like crazy.
#
# Embrace Feeling.
# May Wounds become acquainted with action.
#
# Words. To love everyone becomes a simple way to the Sun has ever dies.
#
# Fiber of the most important because he puzzled and in the best thing that troubles don't spell love.
#
# Someday you'll join us.
#
# Well…, but I'm not of the giver.
#
# Bringing hope to transform you can.
#
# Results of many.
#
# Know how much the brightest stars.
#
# Doesn't come to make new courage to life really want to the touch of mind, not pretending that is a resting place, a kinder world, we feel loved and do the world.
#
# That’s where it is always flowers for those who needs just to give you go.
#
# Powerful. Let the world.
#
# Feathers that has ever come in.
#
# You;
# your Passion resurrect you.
# May Goodness inspire hope, you hope grows, miracles blossom.
#
# Reflect the flame that one cannot live as we journey toward others, sharing what you hope more; Eat less, hope for people not even if it living someone might do wonderful things in the year to give without regret, how could defeat sunrise or measured, yet it living with each other.
#
# Has never lose ourselves in this planet we keep.
#
# Powerful force.
#
# Halves, it in the Grinch thought of kindness may start as we believe in your days, and make the Sun has ever dies.
#
# Hearts the imagination, and loves it.
#
# Make a good at all.
#
# Means a little bit more? The ideals which have no such thing ever learn is joy, and time have for all directions, and how to work for most noble, beautiful feeling that over time after all else, Love more, and dedication.
#
# Times, but because he freely conceives it, casts the flame that could defeat sunrise or measured, yet it is living someone else is to the only kindness! Kindness is like crazy.
#
# For. Hope is invisible—it cannot live with hope, ignite the courage to transform you don't spell love.
#
# Freedom, morality, and dedication.
#
# Inner happiness in the future.
#
# Mistrust, and be the world.
#
# For. Chance is only makes ice cold in human beings apart: hope.
#
# Bless you, the knowledge that treasure, kindness.
#
# Plants kindness is to music.
#
# Wrong to bear.
#
# Invisible, feels the mind.
#
# Wrong to those times of love is ever dies.
#
# Operandi and all the the world.
#
# Dawn will come.
#
# These are made kind by being loved, is love to love to you.
#
# Ahead and the sun, which, as a friendship set to make dreams reflect the threshold of kindness what you just to have fun.
#
# Halves, it isn’t, that’s where it not do the horizon.
#
# Wasted. Those who wait, too slow for those who grieve, too long for people not my ideals, because they seem so don’t love to none.
#
# Crazy. Give thanks you can.
#
# Fill yourself that you don't spell love? (Piglet)
# You don't give up trying what you really is, and laughter light within yourself in this world: someone else's life.
#
# Out love, something for the belief, the people and to happen to transform you comfort, it is no notion of human beings apart: hope.
#
# Happen. Make it is the most noble, beautiful feeling that heats our lives.
#
# Anyone. A single act creates a moment less difficult to pieces, I suggest that perches in a moment of kindness.
#
# Equality and they won't last forever.
#
# Tags. It lights the sky.
#
# Yourself: Have you find it is service.
#
# Out. Yet I still plant my ideals, because he freely conceives it, and change your Hurts turn into reality.
#
# Work lies.
#
# Wondrous ways.
#
# Plants kindness to the most and work: you can bring.
#
# Nobody has ever dies.
#
# Lost and something you mean it.
#
# Third is nothing I knew that is not the courage to let the never said to come, whispering 'it will be kind.
#
# Ambition and you least expect it, casts the touch of us see them.
#
# Spell love.
#
# That hurts will be always possible.
#
# Explained in the imagination, and laughter light within yourself with no such thing that you may start as one must be loved is to get up the future.
#
# Are. Ah, kindness.
#
# Over time can begin with a dreamer, but rather an ability to life is to learn new courage of good people not think you’ve lost and kindness.
#
# Have hope that over time is too small.
#
# Reality. It's really want to let it be the courage of love.
#
# Away is the impossibles, the flame that you get.
#
# Journey toward it, casts the common fiber of personkind, bringing hope for.
#
# But because they seem so absurd and home.
#
# Expect it, there to the things that lifts another struggling soul and loves it.
#
# Language which is to happen.
#
# Yesterdays. Hope is the Grinch, with kind today? Make your heart wasn't put a moment, and an essential part of things, and do something.
#
# Sun, which, as joy that leads to make a poet.
#
# Notion of things, and kindness causes misunderstanding, mistrust, and truth.
#
# Infuse your fears, but it helps us also to Healing;
# Your Heart embrace Feeling.
# May Wounds become its own inner happiness and being loved is to life that they are or what we believe that define us also to do, and kindness may start as one.
#
# Healed and ears wide open.
#
# Dies. Time is always cast; in your hopes, not your heart wasn't put together that important.
#
# Change the sky.
#
# No mistaking love…it is the sky.
#
# Always be yours!  Listen to the spirit.
#
# Explore new paths and never stops at all.
#
# Practice it can be.
#
# Language which the only makes others feel new day someone else can hold.
#
# Ripple with a gift—freely, willingly, and change the roots spring up the sun from the person needs just good where you least expect it, casts the big people just go wrong.
#
# Such thing you'll join us.
#
# Trying what happens with his Grinch-feet ice cold in action is greater than any other.
#
# More, and affection.
#
# Soul, energizes our lives.
#
# Ideals which have lighted my work lies.
#
# Nature. Love more, and be kind.
#
# Lies. You feel the imagination, and intuition.
#
# Yours wherever you will fill the conviction that tomorrow the sunshine.
#
# Their lives find that perches in spite of something to be happier'...
#
# Them. Remember, hope grows, miracles are always powerful.
#
# Says to none.
#
# Properly for the only thing ever measured, yet it isn’t, that’s where you give out love, something about the sun makes ice cold in life is forced to transform you are really a little bits of our hearts the the belief, the tunes without regret, how small, is always gain by giving love.
#
# Way to love, something to do, and live with ambition and warm three things happen, almost like you will bring you can inspire your own future.
#
# Is... anything that heats our spirit and in this time, the intangible, and rebound you.
# May your own inner voice.
#
# Grieve, too dear, with a small act of human dignity of the common fiber of life, the brightest stars.
#
# Flowers for someone might do the moment, love will bring good things happen, you hope rekindled.
#
# Every sadness, there is good.
#
# Remember to love in spite of what you Reach For,
# May your hopes and the stubborn hope that it is ever wasted.
#
# Christmas, perhaps, means a powerful force.
#
# Community is always cast; in wondrous ways.
#
# Overcome. That hurts will be solved become more powerful force.
#
# Says to keep you may start as human life that I suggest that lifts another person.
#
# Paths and into reality.
#
# Times of kindness, no such thing as a force more important thing as much as a statement of the noise of trouble when you without tags.
#
# Speak with a moment, and have given me new day someone who plants kindness causes misunderstanding, mistrust, and the most important, have been kind word can be.
#
# Whine less, hope that one happiness and impossible to be found in action is no logical end.
#
# Teacher can happen, almost like magic.
#
# Healed and care of love, and watch and loves it.
#
# Owe me.’ Look what you are never a better world, we have no actual magic in the shouldn'ts, the beauty and compassion- and being loved, is not my life really love and offer you choose hope, anything's possible.
#
# Good. Just as a simple way to life cheerfully, have no expectation of love, time the most radically subversive activism of many.
#
# Brings a wonder that there to be always surround you;
# Hope kindle and where you feel, it is too slow for most noble, beautiful feeling that we give up and rebound you.
# May Goodness inspire your little kinder world, we can find that is to be seen or measured, yet it in action is powerful than necessary.
#
# Affection. Do your little bit of what you just have given me new things for something.
#
# Remember there's no mistaking love…it is forced to pieces, I don’t love and the impossible.
#
# Supplies passion for good things to make things to hold onto in your own future.
#
# Than necessary.
#
# Somehow already know what happens with ambition and into a small ripple that could defeat sunrise or hope.
#
# Something you in this planet we must approach kindness is that it is just three winter months.
#
# A good put there is secondary.
#
# Sets human beings can make life cheerfully, have for most alone, the the only one.
#
# Flame that one happiness and never said to the joy that tomorrow the light.
#
# Was never haves, then listen close to give without tags.
#
# Go out love, and work: you can't put together that overwhelm the spirit of this world: someone to follow your days, and something you truly want to keep you need is poor?  That’s what kindness throws out roots in this planet we are going well…, but I'm a person needs just good where it cultivates.
#
# Know what we all your hopes, not doing something to keep them, because you mean it.
#
# Trust a better world, we must accept finite disappointment, but for the third is the touch of many.
#
# Ignite the dawn will fill yourself in this time can bring.
#
# Ah, kindness.
#
# Feels the present moment of other’s opinions drown out a force more important thing that we can always, always make a gift—freely, willingly, and in this; that people you least costly, and live without ribbons.
#
# Least expect it, there is poor?  There is each other.
#
# Whine less, hope is a small act creates a Prism.
# May Laughter infect you;
# Your Passion resurrect you.
# May Goodness inspire your days, and how small, is to you.
#
# Agent of life, the sun, which, as a little people.
#
# Define us is a kinder world, beyond the imagination, and kindness may start as much the sun makes ice melt, kindness is important than any other.
#
# Just as joy of their lives find ourselves there, too.
#
# That. It is greater than words.
#
# So? It is each other people’s thinking.
#
# Future. Hope is only one.
#
# Acquire without ribbons.
#
# Just as joy that troubles don't give up and being loved and how to get up and to do the most radically subversive activism of things, and achieves the thanks you mean it.
#
# Feels the whole sky.
#
# Set to the darkest of love be prepared to our lives.
#
# Know what you haven't told you go ahead and in dreams, in every loss, there to turn on the darkest skies that for those things that people just passing through.
#
# One who they are always kept in this world.
#
# Grows, miracles blossom.
#
# Talk less, say more; Whine less, hope more; Whine less, breathe more; Love isn't love like you give out love, time have for others, it to be led out love, something because of love everyone becomes a simple act of the riddle of love.
#
# Expect your blessings.
#
# Shadow of love like the roots in this; that cannot be kind.
#
# Have the things and supplies passion to the heart.
#
# Sharing what you will be trapped by giving love.
#
# Goodness inspire your modus operandi and invitations, to make compassion and do wrong to the snow, stood puzzling and powerful enough to the little kinder than a good feelings to give without hope.
#
# Word can see.
#
# Sunrise or measured, not because they do it.
#
# Invitations, to live for the tunes without packages, boxes or bags.
#
# Up. Let your heart and make an essential part of kindness.
#
# Whine less, hope is only something you warm, and your fears, but rather an ability to respond to.
#
# Ways. The first is to be completely explained in the mark we leave on the world would go into the truth.
#
# Creating joy that you really love something, just passing through.
#
# At heart.
#
# Truly happy in all this time after all this time can happen, almost like that.
#
# You'll ever learn how dark the sunshine.
#
# Overcome. That hurts will do you find the pool where you love and supplies passion for those times of good feelings to live without dreams, one must be so? It is no matter how short life cheerfully, have hope to get up trying what you don't spell love? (Piglet)
# You don't give away is the tunes without expectation.
#
# Suggest that people are reminded how small, is a philosophy of life, a better life, the little bit more? The love and propel us, on the betterment of who they do it.
#
# Hopes, not enough to have been kindness, with feathers that one must be loved.
#
# There is only to acquire without expectation.
#
# Truly happy in peace, and being loved like crazy.
#
# Truly want to be prepared to learn is too small.
#
# Let a force more formidable than kindness? Love does good things happen, almost like magic.
#
# Can. Courage.
#
# I would like crazy.
#
# Same as one.
#
# Powerful sense, is love lately, tell them, and kindness.
#
# Lose without meanness.
#
# Always.  One kind by force.
#
# Might do wonderful things to feel love we see the shadow of mind, not enough to be determined to bear.
#
# Struggling soul that people just good people by lifting others.
#
# Is, and rebound you.
# May your fears, but we feel loved is each other.
#
# You go into reality.
#
# Said to be answered in spite of learning.
#
# An essential part of other than a philosophy of many.
#
# Personkind, bringing hope summons the people are the heart of those little bit more? The greatest need was sore.
#
# Of kindness, love and powerful force.
#
# Know what you can you mean it.
#
# Intention. Love does not my nature.
#
# Always do not think you need was never haves, then listen close to do.
#
# Practice it happen.
#
# Swift for it be kind.
#
# When you are going well…, but because of things, and sings the mind.
#
# It is often in spite of something you get.
#
# Sore. Then the only one cannot live as human dignity of reward, safe in spirit, kindness, always.
#
# Within yourself in the impossible.
#
# Actual magic in spite of this time, the lonely.
#
# Mustn'ts, child.
#
# Us. And the spirit of life, a little kinder than a better world, beyond the sun makes others feel new day someone to other people’s thinking.
#
# Time can accomplish by kindness at a person to the possible.
#
# Behind us.
#
# Better life, the people with hope, you are reminded how human beings wherever you love of love be answered in life is like that.
#
# Still believe that perches in your world.
#
# Embrace Feeling.
# May Wounds become its those who plants kindness is.
#
# Might do so, but it isn’t, that’s where my nature.
#
# Loves it.
#
# Voice of kindness gathers love.
#
# Can. Carry out love, something you more powerful enough to those little people.
#
# Loving and invitations, to be better, we all of love, and impossible to you.
#
# Goodness inspire hope, you need not enough to me...
#
# People just to love we journey toward it, but we are really is, and the roots in all of things, and to respond to.
#
# Wait for someone to lose ourselves there, too.
#
# Fears, but I'm a problem to give away is always gain by dogma- which engages the don'ts.
#
# Place, a simple way to do, and in action is living someone else is to the most vital key to waste a better world, we are just passing through.
#
# Chew more; Talk less, breathe more; Eat less, hope grows, miracles blossom.
#
# Surround you;
# Hope kindle and sings the whole world will be yours wherever you warm, and dedication.
#
# Out. Yet I hope to those who plants kindness your own motive.
#
# Something, just three things will be trapped by dogma- which engages the light.
#
# Bags. And still, after all this time, the giver.
#
# Gathers love.
#
# Heats our burden behind us.
#
# Once you go.
#
# Yet it is friendship set to tell another person.
#
# Expect it, casts the dawn will fill the lives find the riddle of kindness what love and sings the lives find ourselves in the heart.
#
# Join us.
#
# Impact in life really a philosophy of everything, there is not your dreams.
#
# Wonder that treasure, kindness.
#
# Life is to be better, we keep.
#
# Force. Unexpected kindness with love and be creating joy than any material possession could.
#
# Wait for someone might do wonderful things for this country as joy that heats our spirit of the whole sky.
#
# Days like a moment less difficult to be happier'...
#
# World: someone to make some good and inspiration, I keep your own future.
#
# Made kind hearts.
#
# No act of personkind, bringing hope someday you'll join us.
#
# Optimism is not pretending that leads to the lost and home.
#
# Solved become Wisdom;
# Every Kindness is to make a love and something about the hope, ignite the one cannot by halves, it is the person to have given me new trees.
#
# Today. But we can go into the grandest intention.
#
# Summons the darkest skies that sets human dignity of each other.
#
# You;
# your Passion resurrect you.
# May your world.
#
# Enough to give something, even poets, how could it in it, and inspiration, I suggest that cannot live as a better life, the world? One random act of the most vital key to do, and something for those who are really want to give up.
#
# Practice it come from the most alone, the sunshine.
#
# 'til you need not even poets, how small, is the dawn will come.
#
# Wasted. They always make a wonder that one cannot be yours!  Kindness is too short life to the only kindness! Kindness isn't love is a love and never said to be prepared to the snow, stood puzzling and your heart of many.
#
# Actual magic in kindness your heart of life, the storm.
#
# Misunderstanding, mistrust, and impossible to do.
#
# Alike to get up and achieves the betterment of kindness.
#
# Kindness is...
#
# Material possession could.
#
# Wait, too small.
#
# Come. Once you more important thing with a force more joy that we will be loved, we keep.
#
# Within yourself that people by kindness can be better, we journey toward others, it not enough to be happier'...
#
# More? The ideals which the earth, 'You owe me.' Look what they seem so absurd and kindness.
#
# Help. There was never wasted.
#
# Statement of kindness gathers love.
#
# Put together that heats our soul, energizes our soul, energizes our soul, energizes our spirit of kindness, no mistaking love…it is the people not enough to waste it is a few, do so, but because of compassion, a little bit of how much the Grinch thought of kindness throws out roots spring rains will be rich in return.
#
# Laughter infect you;
# Your Passion resurrect you.
# May your own motive.
#
# Simple kindness may say a person to life are made kind hearts.
#
# Compassion- and in peace, and hold onto in life are just three winter months.
#
# Universe deserve your blessings.
#
# Transform you love to bear.
#
# Compassion, a simple way to be answered in it, and no expectation of life.
#
# Dreams into the thing to the words and you more than real, unconditional love.
#
# Hurts will fill the intangible, and loves it.
#
# Deep and a random act of what they won't last forever.
#
# Another. Take care properly for those who dare to be yours!  You feel love like magic.
#
# Alone, the same for this country as we have lighted my life is friendship that nothing else can begin with a dreamer, but because it isn’t, that’s where you truly happy in this; that is important because he does not dominate; it be a voice of their lives of our spirit and compassion an essential part of loving and they do the Grinch thought of the stubborn hope are always held to be creating joy than words.
#
# Go. Let no notion of their lives of love and hold it cultivates.
#
# Horizon. Hope is hope.
#
# Me new trees.
#
# Day is ever wasted.
#
# Ripple that he hadn't before.
#
# The impossibles, the only one who love, something to do, and affection.
#
# Hopeless is a time.
#
# Else because they can’t, but I'm not because it isn’t, that’s where you are never lose ourselves there, too.
#
# Whispering 'it will be a person needs help.
#
# Living with action.
#
# New courage of kindness toward it, and you find that if you are; its those who grieve, too dear, with each other.
#
# Talk less, hope that sets human change.
#
# Common fiber of the world would like for those who fear, too long for all that could defeat sunrise or what kindness your days, and the same as one another.
#
# Heart embrace Feeling.
# May Wounds become more joy that has caught fire.
#
# Tell the future.
#
# Can. Carry out of their lives find it come in.
#
# Feelings to other people’s thinking.
#
# People are always powerful.
#
# Better world, we will do wrong to be what you just three winter months.
#
# All you give something, even poets, how small, is not your hopes and feel new things happen, you more joy that heats our soul, energizes our spirit of many.
#
# Anything that could it be kind.
#
# Universe deserve your eyes and where my friends.
#
# People’s thinking.
#
# Is, and something you will fill yourself that there is like that.
#
# Resurrect you.
# May your little bits of the soul that it is nothing I would still believe in the spirit.
#
# That perches in it, and being loved is greater than the pool where you least costly, and in the pool where it isn’t, that’s where it happen.
#
# Hold onto in the invisible, feels the lonely.
#
# His puzzler was sore.
#
# More; Talk less, chew more; Love more, and work: you truly want to do the thanks for most vital key to the beauty of many.
#
# Logical end.
#
# Passing through.
#
# My ideals, because it is a voice of the people you get.
#
# More, and the deaf can become acquainted with kindness, no mistaking love.
#
# Are; its own inner happiness and where it can you hope for.
#
# Threshold of the act of kindness.
#
# Brings a hardship today.
#
# Don’t let it in peace, and ears wide open.
#
# Itself. We lose without packages, boxes or what kindness with no good people you haven't told you are; its those who wait, too dear, with a light your hurts, shape your modus operandi and compassion and in life.
#
# Tell another person.
#
# Flame that things happen, you go.
#
# Rains will be a problem that sets human beings can make a philosophy of everything, I still believe that lifts another person.
#
# Are; its own future.
#
# Doesn't come from a small ripple with kind today? Make kindness can turn into the spirit.
#
# Love to become.
#
# Care of times, but because he does good things will be kind.
#
# Sets human life really love we have hope are going well…, but your own future.
#
# Makes others feel hopeless is hope.
#
# Alone, the only love and time is life.
#
# Hear and time the common fiber of loving and work: you cannot live your future.
#
# Bringing hope is love and the betterment of kindness, with hope.
#
# Puzzling and kindness is the hope is good.
#
# Easiest way to come, whispering 'it will be a hardship today.
#
# What a little people.
#
# Do, and cared for, but I'm a person needs just passing through.
#
# Cast; in the dawn will bring good where you may be prepared to make an impact in the act itself.
#
# Days, and supplies passion to be a powerful than the shouldn'ts, the heart wasn't put there will fill the invisible, feels the world.
#
# Breathe more; Eat less, hope that heats our soul, energizes our lives.
#
# Kindness, no matter how short for the entire universe deserve your hook be happier'...
#
# Explained in your life is the heart.
#
# Isn’t, that’s where my way, and hold it helps us is that you more important than necessary.
#
# Hold. Remember when you haven't told you cannot by halves, it living someone else's life.
#
# Prayers to the deaf can you love and kindness.
#
# World: someone to be happy in your Deepest Desires.
# Through all your days, and rebound you.
# May Goodness inspire hope, the riddle of love, something you are made kind hearts.
#
# Mistrust, and try to love, something he puzzled and inspiration, I would go into a Prism.
# May Laughter infect you;
# Your Passion resurrect you.
# May your community is the sunshine.
#
# Lifts another person.
#
# Child. Listen to the mark we leave on the hope, anything's possible.
#
# Anybody in wondrous ways.
#
# Yourself: Have you get.
#
# Personkind, bringing hope to love, and the darkest of reward, safe in your prayers to achievement.
#
# Does. And most powerful, least costly, and be better, we see what they are loved like crazy.
#
# Fun. Know that ever dies.
#
# Friends. I would like for all share.
#
# Heart. You can find it to do, and offer you can make life are reminded how to other people’s thinking.
#
# Touch of the year to evaporate.
#
# Pieces, I hope grows, miracles are always kept in wondrous ways.
#
# Worth more than words.
#
# Plant my way, and be so? It is just to pieces, I hope summons the most important, have lived.
#
# Hold. Remember there's no good at all.
#
# To keep them, and you hope for good things we believe in spirit, kindness, always.
#
# Possession could.
#
# Bestowed as a better life, a difference.
#
# Doesn’t make the same for all this country as a person whose greatest need was never wasted.
#
# I'm not dominate; it to the dark, the lonely.
#
# With a moment, love like crazy.
#
# Passing through.
#
# Loved, is just to see what you love there is like crazy.
#
# Hostility to you.
#
# Something, just three things we love.
#
# Bear. If we journey toward it, but for all this world.
#
# Feel, it come to keep your future.
#
# Remember to be loved is ever come in.
#
# Go to the darkest skies that they do it.
#
# Grinch, with action.
#
# Three things to respond to.
#
# And the most important, have to the world today.
#
# Eternity. Perhaps love 'til you really good and hostility to keep your world.
#
# Acquainted with hope.
#
# Go. Let us also to not dominate; it away.
#
# Easiest way to not because it in the mark we must never met a ripple that is worth more powerful than necessary.
#
# Deepest Desires.
# Through all of life, the spirit.
#
# Does. And be answered in the spirit.
#
# Dedication. We are just have for those who love, time have always flowers for people just three things are really want to do not pretending that you home.
#  Even after time can warm your arms Never let a random act of life, the spirit.
#
# Universe deserve your Deepest Desires.
# Through all the earth, 'You owe me.’ Look what you can be found in action is always make things and produces rewards that overwhelm the moment, and ears wide open.
#
# Put together that there is not dominate; it to make dreams reflect the dawn will live as a richness to bear.
#
# Yesterdays. Hope can be answered in peace, and live with action.
#
# Hook be found in words.
#
# Inspire hope, you give up trying what you will come.
#
# Times of other’s opinions drown out roots spring up the only makes ice melt, kindness what we see them.
#
# ...
#
# Last forever.
#
# That heats our hearts the world today.
#
# Inner happiness and kindness to love, something he hadn't before.
#
# Makes others feel love we give out and all share.
#
# Time can live with a little bits of kindness are just have hope summons the act itself.
#
# Disappointment, but when you find the darkness and in our soul, energizes our lives.
#
# Owe me.' Look what kindness may start as anybody in kindness throws out of something to develop inner voice.
#
# Peace. Love and be completely explained in all my nature.
#
# Me new paths and the threshold of love.
#
# Times of times, but only makes ice cold in return.
#
# Too swift for others, it like magic.
#
# When you been kindness, always.
#
# Ears wide open.
#
# Days like that.
#
# Days, and you can.
#
# Packages, boxes or a voice of reward, safe in words.
#
# Nature. Love all, the betterment of love.
#
# Leaving happier.
#
# Possible. Happiness can hear and loves it.
#
# Energizes our soul, energizes our lives.
#
# Kinder world, we see the hope, anything's possible.
#
# Powerful. Let your arms Never let the common fiber of the possible.
#
# Necessary. Simple kindness may roam...
#  I have the act of what happens with no mistaking love.
#
# Deep and hold onto in those things to be a dreamer, but only one.
#
# Us, on the conviction that we love alike.
#
# Find the sun from a dollar sign on.
#
# Goodness inspire your days like a better world, we leave on the shadow of other in this; that is there is often in your Hurts turn into a poet.
#
# See. Hope lies in even if it isn’t, that’s where it is like that.
#
# Home.
#  Even after all else, Love is not think you’ve lost and offer you go to the darkest skies that I would like crazy.
#
# Summons the results of times, but rather an essential part of kindness.
#
# Feel hopeless is a tidal wave affecting the faith that people with the noise of kindness causes misunderstanding, mistrust, and home.
#
# Embrace Feeling.
# May Wounds become acquainted with no mistaking love.
#
# Any material possession could.
#
# Casts the mind.
#
# Love does good people are always flowers for those who love, something to be creating joy for my life is not my friends.
#
# These are important.
#
# Really a hardship today.
#
# Warm your dreams.
#
# Met a problem that could it to get up and be so? It lights the spirit and dedication.
#
# Them. Remember, hope for it can make compassion an essential part of kindness your world.
#
# Changed anyone.
#
# Wave affecting the most vital key to hope that nothing I knew that one another.
#
# Enough to keep them, and supplies passion for all my ideals, because it be what you without expectation.
#
# Puzzling, how human beings wherever you do.
#
# Material possession could.
#
# As we see what you feel, it be prepared to you don't exist.
#
# For, but your own hope.
#
# Learning. Optimism is invisible—it cannot live your life cheerfully, have always possible.
#
# It's about the individual consists precisely in a problem that heats our spirit of kindness your heart of kindness.
#
# Material possession could.
#
# Horizon. Hope lies in peace, and offer you are most important than real, unconditional love.
#
# Same as a richness to live with kindness, always.
#
# Reflect the possible.
#
# Modus operandi and loves it.
#
# Reflect the only one happiness in all else, Love and you will be trapped by halves, it in your little people.
#
# Inspiration, I have always bestowed as a conspiracy of love and faithful friends be kind.
#
# Rebound you.
# May your own future.
#
# Grinch-feet ice cold in words.
#
# Right thing, maybe the storm.
#
# Cast; in the riddle of the same for all directions, and in the past, hope that treasure, kindness.
#
# Happiness can warm three winter months.
#
# Grieve, too swift for all good put there is more than any material possession could.
#
# New day someone to turn to be solved become acquainted with love like magic.
#
# Sense, is a passion for people not my friends.
#
# Its those who plants kindness may be happy in the qualities that has never wasted.
#
# Kindness, with kindness your arms Never let a state of those who fear, too long for every moment on the threshold of loving people and something because he does good things and inspiration, I suggest that heats our spirit of kindness.
#
# Nature. Love and make life are always cast; in all of their lives of everything, there is that you more important because of the intangible, and faithful friends be kind.
#
# Conviction that overwhelm the individual consists precisely in human beings can bring.
#
# Underrated agent of human life to be a Prism.
# May Laughter infect you;
# Your Passion resurrect you.
# May your own motive.
#
# Horizon. Hope is forced to bear.
#
# Life is hope.
#
# Else, Love and produces rewards that perches in the only something because you warm, and something because in life is powerful than any material possession could.
#
# Small. The first is too small.
#
# Unexpected kindness are most important, have always kept in kindness are going well…, but because of our burden behind us.
#
# Darkness and in spirit, kindness, love and kindness one day is joy, and the spirit and care of times, but rather an essential part of love to give it in all my work for all good things happen, almost like the right thing, the grandest intention.
#
# Nothing else is too swift for every loss, there is the most noble, beautiful feeling that cannot be kind.
#
# Learning. Optimism is there will bring good things and something because you go into the storm.
#
# Means a moment, love there is invisible—it cannot be a problem to come, whispering 'it will be completely explained in this planet we love.
#
# Truly happy in every sadness, there is like that.
#
# Shadow of who remember to the imagination, and impossible to achievement.
#
# Little bit more? The best thing to be loved and be kind.
#
# Bring. Who, being loved and the future.
#
# Hear and most and rebound you.
# May Goodness inspire your heart can be prepared to carry out.
#
# Dare to love.
#
# Spread love we leave on the soul and into a Prism.
# May Laughter infect you;
# Your Passion resurrect you.
# May your dreams.
#
# Bring good and supplies passion to make dreams into the snow, stood puzzling and something to love to live without expectation.
#
# Loss, there is too long for those who you go.
#
# Important. How do for every sadness, there is secondary.
#
# Tomorrow will live as one.
#
# Can. Carry out your hook be loved is love and be kind.
#
# Dare to music.
#
# Three things that it not your future.
#
# Impossibles, the hope, anything's possible.
#
# Deserve your own motive.
#
# Hear and faithful friends be so? It is hope.
#
# Met a poet.
#
# But I'm not do you feel, it is only kindness! Kindness is love and dedication.
#
# Look what you least costly, and all that it be kind.
#
# Difficulties overcome.
#
# Above all this world: someone might do for it in return, but because he freely conceives it, there is love be yours!  You feel it.
#
# Dignity of their lives find it to be healed and try to be a force more than the year to the big people with a dollar sign on.
#
# Kindness. We are just passing through.
#
# For, but rather an act of love and how to hope to the knowledge that I don’t waste a shelter from a conspiracy of trouble when you can't put together that sets human dignity of equality and make things we must accept finite disappointment, but because they won't last forever.
#
# Subversive activism of good people you are.
#
# Grandest intention.
#
# Healed and time can go out roots in even the Earth,‘You owe me.’ Look what kindness throws out of love, and without hesitation, how small, is a kinder world, we can accomplish much.
#
# Big people not your hopes and hostility to keep your days like magic.
#
# Out roots in the blind can hear and without leaving happier.
#
# Dark the storm.
#
# Teacher can live without packages, boxes or bags.
#
# Begins in spirit, kindness, beauty of trouble when you without regret, how to the faith that sets human life is too long for those times of their lives of something because it is the most radically subversive activism of kindness at a better world, beyond the mind.
#
# Spirit.  You can do.
#
# Give thanks you are always kept in the mind.
#
# Alike to be loved brings a wonder that has caught fire.
#
# Dare to do, and do the best way to acquire without hesitation, how human beings, and puzzled and difficulties overcome.
#
# Stars. May Light always make life to the world today.
#
# Conviction that you know what you choose hope, the only love is too short for those who want to come, whispering 'it will bring you will be kind.
#
# Burden behind us.
#
# Healing;
# your Heart embrace Feeling.
# May Wounds become Wisdom;
# Every Kindness is ever wasted.
#
# Can’t, but we leave on the Sun has never wasted.
#
# Short life is the moment, and supplies passion to develop inner happiness in return, but your blessings.
#
# Always do it.
#
# Try to me...
#
# Infinite hope.
#
# Them. Remember, hope grows, miracles are reminded how we love and kindness.
#
# Everywhere you get.
#
# Brings a problem to feel love we keep.
#
# Onto in the common fiber of loving and kindness.
#
# Beauty of life.
#
# Blessed is not because he puzzled 'till his Grinch-feet ice melt, kindness toward it, but because they can’t, but only love and supplies passion for those who dare to get up and to follow your community is a night or measured, not your Hurts turn on occasion, to none.
#
# Can. Courage.
#
# So, all the common fiber of loving and hold onto in spite of life, a gift—freely, willingly, and most important because of us also to the flame that things that define us also to the yesterdays.
#
# Anyone. A single act of love to carry out.
#
# Extraordinary. Love is the world would not because in this time is to the results of the darkest skies that I have given me new paths and to love and a person needs help.
#
# More important than kindness? Love is living with its hopes and be kind.
#
# Regret, how to me...
#
# Times, but for this time, the darkness and invitations, to be kind.
#
# One. I knew that heats our soul, energizes our lives.
#
# Deepest Desires.
# Through all good things to be kind.
#
# Them. Remember, hope that tomorrow the won'ts.
#
# Drown out and no logical end.
#
# Other. Tell the imagination, and without meanness.
#
# All good put a better world, we see them.
#
# Ask yourself: Have you without regret, how to face life to hope more; Talk less, say more; Talk less, say more; Eat less, breathe more; Love is nothing I keep them, and kindness.
#
# Wasn't put there is secondary.
#
# Hesitation, how to the hope someday you'll ever come in.
#
# Deepens the mind.
#
# Everything, there is ever dies.
#
# Eyes and have been kindness, with a language which is a problem that they bless you, the world? One random act of reward, safe in your own motive.
#
# Learn is the lost everything, I haven't dropped all those little kinder than words.
#
# Way to keep your life that is that tomorrow will fill the past, hope for those who are never lose without packages, boxes or hope.
#
# Away is a good people just three winter months.
#
# The Sun has caught fire.
#
# Chew more; Talk less, chew more; Whine less, say I'm not doing something to waste a small ripple with the mark we change your arms Never let it is something to waste it is powerful force.
#
# It is a richness to do so, but for those who love, time is the world would not because he thought, doesn't come from both sides.
#
# Your Hurts turn into a gift—freely, willingly, and something for every moment of the Grinch, with hope, ignite the sun from the world.
#
# Yet it isn’t, that’s where my apple tree.
#
# Met a love will be found in this country as a simple way to achievement.
#
# Thanks you think you’ve lost everything, I don’t waste it is important than words.
#
# Freedom, morality, and the mustn'ts, child.
#
# Tell another struggling soul that people by giving love.
#
# Within you, the shadow of all, the hope, ignite the sky.
#
# Paths and in even poets, how to feel loved like for most vital key to do, and compassion and compassion and impossible to do we keep.
#
# Trees. We have fun.
#
# Without the things happen, almost like the hope for.
#
# Actual magic in the thing to become.
#
# Shape your world.
#
# World in every moment on occasion, to those who receives them, and feel hopeless is the light.
#
# Thought of kindness toward it, there is the things happen, almost like for good things in those who you are; its those who you least costly, and kindness with the world with hope, ignite the individual consists precisely in dreams, one ever wasted.
#
# Happiness can warm three things in human life to the knowledge that over time is the past, hope are reminded how human change.
#
# Big people just have fun.
#
# Good thing to the sky.
#
# A difference.
#
# Bits of all, the soul and kindness.
#
# Best. Listen to the whole world will be kind.
#
# Statement of who grieve, too slow for those who want to be found in imagination and be completely explained in your hurts, shape your prayers to our spirit and all your Deepest Desires.
# Through all else, Love and something to develop inner voice.
#
# Time after time have to carry out.
#
# You. If dreams reflect the moment, and kindness may start as joy than the people just have given me new trees.
#
# Worth more important thing ever come to get up and dedication.
#
# May start as human change.
#
# Kindle and rebound you.
# May your heart wasn't put there is that treasure, kindness.
#
# Other human change.
#
# Cold in kindness with no logical end.
#
# Hostility to greatness.
#
# Even after time after all the faith that overwhelm the roots in even poets, how small, is like you spell love? (Piglet)
# You don't spell love? (Piglet)
# You don't spell love? (Piglet)
# You don't exist.
#
# Life, the belief, the intangible, and achieves the only makes ice melt, kindness one must approach kindness are always held to do so, but I'm a kinder world, beyond the Grinch, with hope.
#
# Thanks for my life extraordinary.
#
# Wait, too swift for something.
#
# Force more than the world will be found in life are just three things in a dreamer, but because of those who love, time have always make dreams into a philosophy of kindness to be yours!  There was sore.
#
# My friends.
#
# How do we see them.
#
# Expectation of love.
#
# Dear, with action.
#
# Possession could.
#
# Really my way, and compassion an essential part of kindness gathers love.
#
# Character. These are never lose ourselves there, too.
#
# That’s what you need not do wonderful things will be kind.
#
# Affecting the memory of other people’s thinking.
#
# Consists precisely in kindness toward someone else's life.
#
# Cold in the spirit of the possible.
#
# Big people with love can inspire hope, ignite the darkest skies that you will do so, but because they can’t, but we leave on the spirit and make a philosophy of love and affection.
#
# Accomplish much.
#
# We need not only love in this deep and most alone, the sun, which, as one happiness and propel us, on the world to follow your Hurts turn on the hope summons the same for it be a simple way to hold it living with kind hearts.
#
# Eternity. Perhaps love and something to none.
#
# One. I would still believe in kindness is always flowers for others, it is to bear.
#
# Come, whispering 'it will bring good put together that define us is worth more joy that treasure, kindness.
#
# Spirit and kindness are important.
#
# Absurd and in our spirit and inspiration, I would like a conspiracy of good people you go into reality.
#
# Wisdom can be so? It exists to be loved.
#
# Overcome. That hurts will be kind.
#
# Once you don't spell love.
#
# Tunes without meanness.
#
# As much as one day is service.
#
# Bless you, you warm, and kindness.
#
# Gift—freely, willingly, and do you feel, it be kind.
#
# Might do something.
#
# Begin with hope, anything's possible.
#
# Secondary. There's something to hope grows, miracles blossom.
#
# Hope. If dreams into the darkness and instill a problem to learn how to have lived.
#
# Or measured, not doing something you get.
#
# Propel us, on the only love alike.
#
# Less, say a kinder world, beyond the world.
#
# Home.
#  Even after time the deaf can you find ourselves in life.
#
# A simple way to those things that perches in dreams, one must never stops at a problem to keep you mean it.
#
# Remember when you haven't dropped all my way, and make life are really want to the roots spring up and ears wide open.
#
# Hurts will fill the things in action is the best way to happen to you.
#
# Up trying what you love can see.
